# %% [markdown]
# <a href="https://colab.research.google.com/github/lukasztracz195/NeuralNetworkGANToGenZeroFromMNIST/blob/main/MNIST_ZERO_GAN_1000_epocs_version_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Implementacja sieci GAN do nauczenia się jak wygląda liczba 0

# %% [markdown]
# ##Import bibliotek

# %% [markdown]
# ###Ustawienie odpowiedniej biblioteki TensoreFlow

# %%
# To determine which version you're using:
# !pip show tensorflow

# For a specific version:
# !pip install tensorflow==2.4
# Out:
# Name: tensorflow
# Version: 2.4.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: termcolor, opt-einsum, wrapt, wheel, flatbuffers, absl-py, six, grpcio, protobuf, keras-preprocessing, google-pasta, typing-extensions, tensorflow-estimator, astunparse, gast, numpy, h5py, tensorboard
# Required-by: Keras, fancyimpute
# Requirement already satisfied: tensorflow==2.4 in /usr/local/lib/python3.6/dist-packages (2.4.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (3.7.4.3)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (1.1.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (0.3.3)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (2.4.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (2.4.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (1.19.4)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (0.36.2)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (1.32.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (3.3.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (1.1.2)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (0.2.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (3.12.4)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (1.12.1)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (1.12)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (0.10.0)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (2.10.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.4) (1.6.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow==2.4) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow==2.4) (1.7.0)
# Collecting setuptools>=41.0.0
#   Downloading https://files.pythonhosted.org/packages/34/b6/33396512781ec5c40de2e70e8a68f2d0c4d91d6cc182410788c34a00002d/setuptools-51.1.1-py3-none-any.whl (2.0MB)
#      |████████████████████████████████| 2.0MB 12.4MB/s
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow==2.4) (0.4.2)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow==2.4) (1.17.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow==2.4) (3.3.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow==2.4) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4) (4.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4) (4.6)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4) (3.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow==2.4) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4) (3.4.0)
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: setuptools
#   Found existing installation: setuptools 39.1.0
#     Uninstalling setuptools-39.1.0:
#       Successfully uninstalled setuptools-39.1.0
# Successfully installed setuptools-51.1.1

# %% [markdown]
# ###Instalacja odpowiedniej biblioteki Keras

# %%
# !pip3 install keras==2.4
# !pip3 show keras
# Out:
# Requirement already satisfied: keras==2.4 in /usr/local/lib/python3.6/dist-packages (2.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras==2.4) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras==2.4) (1.4.1)
# Requirement already satisfied: tensorflow>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from keras==2.4) (2.4.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras==2.4) (1.19.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras==2.4) (2.10.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.1.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.1.2)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (0.36.2)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (2.4.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (0.2.0)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (0.3.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0rc0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (2.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (3.12.4)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.32.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (0.10.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (3.7.4.3)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.6.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.12)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.12.1)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (3.3.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->keras==2.4) (1.15.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (3.3.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (0.4.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (51.1.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (2.23.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (1.7.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (1.17.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (3.3.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (2.10)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (4.6)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (0.2.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (3.4.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow>=2.2.0->keras==2.4) (0.4.8)
# Name: Keras
# Version: 2.4.0
# Summary: Deep Learning for humans
# Home-page: https://github.com/keras-team/keras
# Author: Francois Chollet
# Author-email: francois.chollet@gmail.com
# License: MIT
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: numpy, pyyaml, tensorflow, h5py, scipy
# Required-by: textgenrnn, keras-vis, kapre, fancyimpute

# %% [markdown]
# ###Instalacja odpowiednich zbiorów danych

# %%
# %%bash
# pip install python-mnist
# pip install tensorflow-datasets
# Out:
# Requirement already satisfied: python-mnist in /usr/local/lib/python3.6/dist-packages (0.7)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.6/dist-packages (4.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (4.41.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (0.10.0)
# Requirement already satisfied: attrs>=18.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (20.3.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (0.1.5)
# Requirement already satisfied: promise in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (2.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (1.1.0)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (0.26.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (0.16.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (1.15.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (2.23.0)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (1.19.4)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (3.12.4)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (3.3.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.6/dist-packages (from tensorflow-datasets) (0.3.3)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow-metadata->tensorflow-datasets) (1.52.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->tensorflow-datasets) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->tensorflow-datasets) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.0->tensorflow-datasets) (2020.12.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow-datasets) (51.1.1)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.9"->tensorflow-datasets) (3.4.0)

# %% [markdown]
# #Zamontowanie dysku google

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import numpy as np
import time
from tensorflow.keras import layers

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Reshape
from keras.layers import Conv2D, Conv2DTranspose, UpSampling2D
from keras.layers import LeakyReLU, Dropout
from keras.layers import BatchNormalization
from keras.optimizers import Adam, RMSprop

import matplotlib.pyplot as plt

# %% [markdown]
# #Implementacja klasy ElapsedTimer

# %%
import time
class ElapsedTimer(object):
    def __init__(self):
        self.__start_time = time.time()

    @staticmethod
    def __elapsed(sec):
        if sec < 60:
            return str(sec) + " sec"
        elif sec < (60 * 60):
            return str(sec / 60) + " min"
        else:
            return str(sec / (60 * 60)) + " hr"

    def elapsed_time(self):
        print("Elapsed: %s " % self.__elapsed(time.time() - self.__start_time))

# %% [markdown]
# #Implementacja klasy DCGAN

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential
import time

class DCGAN:
    def __init__(self, img_rows=28, img_cols=28, channel_color=1):
        self.__img_rows = img_rows
        self.__img_cols = img_cols
        self.__channel = channel_color
        self.__discriminator = None  # discriminator
        self.__generator = None  # generator
        self.__adversarial_model = None  # adversarial model // model przeciwności
        self.__discriminator_model = None  # discriminator model // model dyskrymiancji
        self.__optimizer_for_discriminator_model = None
        self.__loss_for_discriminator_model = None
        self.__metrics_for_discriminator_model = None
        self.__optimizer_for_adversarial_model = None
        self.__loss_for_adversarial_model = None
        self.__metrics_for_adversarial_model = None
        self.__path_to_save_images = None
        self.__train_X = None
        self.__train_Y = None
        self.__loss_history_for_generator = list()
        self.__accuracy_history_for_generator = list()
        self.__duration_history_for_generator = list()

        self.__loss_history_for_discriminator = list()
        self.__accuracy_history_for_discriminator = list()
        self.__duration_history_for_discriminator = list()

    @property
    def loss_history_for_generator(self):
        return self.__loss_history_for_generator

    @property
    def accuracy_history_for_generator(self):
        return self.__accuracy_history_for_generator

    @property
    def duration_history_for_generator(self):
        return self.__duration_history_for_generator

    @property
    def loss_history_for_discriminator(self):
        return self.__loss_history_for_discriminator

    @property
    def accuracy_history_for_discriminator(self):
        return self.__accuracy_history_for_discriminator

    @property
    def duration_history_for_discriminator(self):
        return self.__duration_history_for_discriminator

    @property
    def img_rows(self):
        return

    @img_rows.setter
    def img_rows(self, value):
        self.__img_rows = value

    @property
    def img_cols(self):
        return self.__img_cols

    @img_cols.setter
    def img_cols(self, value):
        self.__img_cols = value

    @property
    def channel(self):
        return self.__channel

    @channel.setter
    def channel(self, value):
        self.__channel = value

    @property
    def discriminator(self):
        return self.__discriminator

    @discriminator.setter
    def discriminator(self, value):
        self.__discriminator = value

    @property
    def generator(self):
        return self.__generator

    @generator.setter
    def generator(self, value):
        self.__generator = value

    @property
    def loss_for_discriminator_model(self):
        return self.__loss_for_discriminator_model

    @loss_for_discriminator_model.setter
    def loss_for_discriminator_model(self, value):
        self.__loss_for_discriminator_model = value

    @property
    def optimizer_for_discriminator_model(self):
        return self.__optimizer_for_discriminator_model

    @optimizer_for_discriminator_model.setter
    def optimizer_for_discriminator_model(self, value):
        self.__optimizer_for_discriminator_model = value

    @property
    def metrics_for_discriminator_model(self):
        return self.__metrics_for_discriminator_model

    @metrics_for_discriminator_model.setter
    def metrics_for_discriminator_model(self, value):
        self.__metrics_for_discriminator_model = value

    @property
    def loss_for_adversarial_model(self):
        return self.__loss_for_adversarial_model

    @loss_for_adversarial_model.setter
    def loss_for_adversarial_model(self, value):
        self.__loss_for_adversarial_model = value

    @property
    def optimizer_for_adversarial_model(self):
        return self.__optimizer_for_adversarial_model

    @optimizer_for_adversarial_model.setter
    def optimizer_for_adversarial_model(self, value):
        self.__optimizer_for_adversarial_model = value

    @property
    def metrics_for_adversarial_model(self):
        return self.__metrics_for_adversarial_model

    @metrics_for_adversarial_model.setter
    def metrics_for_adversarial_model(self, value):
        self.__metrics_for_adversarial_model = value

    @property
    def path_to_save_images(self):
        return self.__path_to_save_images

    @path_to_save_images.setter
    def path_to_save_images(self, value):
        self.__path_to_save_images = value

    @property
    def discriminator_model(self):
        if self.__discriminator_model:
            return self.__discriminator_model
        self.__discriminator_model = Sequential()
        self.__discriminator_model.add(self.discriminator)
        # print("discriminator_model {loss= ",self.__loss_for_discriminator_model,
        #       " optimizer= ",self.__optimizer_for_discriminator_model,
        #       " metrics= ",self.__metrics_for_discriminator_model)
        self.__discriminator_model.compile(loss=self.__loss_for_discriminator_model,
                                           optimizer=self.__optimizer_for_discriminator_model,
                                           metrics=self.__metrics_for_discriminator_model)
        return self.__discriminator_model

    @property
    def adversarial_model(self):
        if self.__adversarial_model:
            return self.__adversarial_model
        discriminator = self.discriminator
        discriminator.trainable = False
        self.__adversarial_model = Sequential()
        self.__adversarial_model.add(self.generator)
        self.__adversarial_model.add(discriminator)
        # print("adversarial_model {loss= ",self.__loss_for_adversarial_model,
        #       " optimizer= ",self.__optimizer_for_adversarial_model,
        #       " metrics= ",self.__metrics_for_adversarial_model)
        self.__adversarial_model.compile(loss=self.__loss_for_adversarial_model,
                                         optimizer=self.__optimizer_for_adversarial_model,
                                         metrics=self.__metrics_for_adversarial_model)

        return self.__adversarial_model

    def train(self, train_X, train_Y, train_steps=10, batch_size=256, save_interval=0, debug=False):
        self.__train_X = train_X
        self.__train_Y = train_Y
        self.__clear_statistics()
        noise_input = None
        if save_interval > 0:
            noise_input = np.random.uniform(-1.0, 1.0, size=[16, 100])

        for i in range(train_steps):
            start_d = time.time()
            images_train = self.__train_X[np.random.randint(0, self.__train_X.shape[0], size=batch_size), :, :, :]
            noise = np.random.uniform(-1.0, 1.0, size=[batch_size, 100])
            images_fake = self.generator.predict(noise)
            if debug == True:
              print('images_train.shape= ', images_train.shape)
              print('images_fake.shape= ', images_fake.shape)
            x = np.concatenate((images_train, images_fake))
            y = np.ones([2 * batch_size, 1])
            y[batch_size:, :] = 0
            d_loss = self.discriminator_model.train_on_batch(x, y)
            end_d = time.time()
            duration_d = end_d - start_d
            start_g = time.time()
            y = np.ones([batch_size, 1])
            noise = np.random.uniform(-1.0, 1.0, size=[batch_size, 100])
            a_loss = self.adversarial_model.train_on_batch(noise, y)
            end_g = time.time()
            duration_g = end_g - start_g
            self.__save_statistics(discriminator_stat=d_loss, discriminator_duration=duration_d,
                                   generator_stat=a_loss, generator_duration=duration_g)
            log_message = "%d: [Discriminator loss: %f, acc: %f | duration: %f s]" % (
                i, d_loss[0], d_loss[1], duration_d)
            log_message = "%s  [Generator loss: %f, acc: %f | duration: %f s]" % (
                log_message, a_loss[0], a_loss[1], duration_g)
            print(log_message)
            if save_interval > 0 and noise_input is not None:
                if ((i + 1) % save_interval) == 0:
                    self.plot_images(save2file=True, samples=noise_input.shape[0], noise=noise_input,
                                     step=(i + 1))

    def plot_images(self, save2file=False, fake=True, samples=16, noise=None, step=0):
        filename = 'mnist.png'
        if fake:
            if noise is None:
                noise = np.random.uniform(-1.0, 1.0, size=[samples, 100])
            else:
                filename = "mnist_%d.png" % step
            images = self.generator.predict(noise)
        else:
            i = np.random.randint(0, self.__train_X.shape[0], samples)
            images = self.__train_X[i, :, :, :]

        plt.figure(figsize=(10, 10))
        for i in range(images.shape[0]):
            plt.subplot(4, 4, i + 1)
            image = images[i, :, :, :]
            image = np.reshape(image, [self.__img_rows, self.__img_cols])
            plt.imshow(image, cmap='gray')
            plt.axis('off')
        plt.tight_layout()
        if save2file:
            plt.savefig(self.__path_to_save_images + '/' + filename)
            plt.close('all')
        else:
            plt.show()

    def __clear_statistics(self):
        self.__loss_history_for_generator = list()
        self.__accuracy_history_for_generator = list()
        self.__duration_history_for_generator = list()

        self.__loss_history_for_discriminator = list()
        self.__accuracy_history_for_discriminator = list()
        self.__duration_history_for_discriminator = list()

    def __save_statistics(self, discriminator_stat, generator_stat, discriminator_duration, generator_duration):
        self.__loss_history_for_generator.append(generator_stat[0])
        self.__accuracy_history_for_generator.append(generator_stat[1])
        self.__duration_history_for_generator.append(generator_duration)

        self.__loss_history_for_discriminator.append(discriminator_stat[0])
        self.__accuracy_history_for_discriminator.append(discriminator_stat[1])
        self.__duration_history_for_discriminator.append(discriminator_duration)

# %% [markdown]
# #Zdefiniowanie funckji dla wykresów

# %%
def make_accuracy_plot(history):
  """
  Funckja zwraca wykres dokładności (accuracy) modelu na zbiorze treningowym.
  """

  import matplotlib.pyplot as plt
  import seaborn as sns
  sns.set()
  # acc = history.history['accuracy'], history.history['val_accuracy']
  acc = history
  epochs = range(1, len(acc)+1)

  plt.figure(figsize=(10,8))
  plt.plot(epochs, acc, label='Dokladność trenowania', marker='o')
  # plt.plot(epochs, val_acc, label='Dokladność walidacji', marker='o')
  plt.legend()
  plt.title('Dokładność trenowania')
  plt.xlabel('Epoki')
  plt.ylabel('Dokładność')
  plt.show()



def make_loss_plot(history):
  """
  Funkjca zwraca wykres straty (loss) modelu na zbiorze treningowym
  """

  import matplotlib.pyplot as plt
  import seaborn as sns
  sns.set()
  # loss, val_loss = history.history['loss'], history.history['val_loss']
  loss = history
  epochs = range(1, len(loss)+ 1)

  plt.figure(figsize = (10,8))
  plt.plot(epochs, loss, label='Strata trenowania', marker='o')
  # plt.plot(epochs, val_loss, label="Strata walidacji", marker='o')
  plt.legend()
  plt.title('Strata trenowania')
  plt.xlabel('Epoki')
  plt.ylabel('Strata')
  plt.show()

def make_durration_plot(history):
  """
  Funkjca zwraca wykres czasu wykonania modelu na zbiorze treningowym
  """

  import matplotlib.pyplot as plt
  import seaborn as sns
  sns.set()
  # loss, val_loss = history.history['loss'], history.history['val_loss']
  duration = history
  epochs = range(1, len(duration)+ 1)

  plt.figure(figsize = (10,8))
  plt.plot(epochs, duration, label='Czas wykonania', marker='o')
  # plt.plot(epochs, val_loss, label="Strata walidacji", marker='o')
  plt.legend()
  plt.title('Czas wykonanaia')
  plt.xlabel('Epoki')
  plt.ylabel('Czas wykonania w s')
  plt.show()

# %% [markdown]
# ##Utworzenie instancji klasy DCGAN

# %%
dcgan = DCGAN()

# %% [markdown]
# #Utworzenie sieci dla modułu generatora

# %%
from tensorflow.keras.models import Sequential
# from keras.models import Sequential
generator = Sequential()
dropout = 0.4
depth = 64 + 64 + 64 + 64
dim = 28
dim_output = 28
# In: 100
# Out: dim x dim x depth
generator.add(Dense(units=dim * dim * depth, input_dim=100))
generator.add(Activation('relu'))
generator.add(Reshape((dim, dim, depth)))

# In: dim x dim x depth
# Out: 2*dim x 2*dim x depth/2
generator.add(Conv2DTranspose(int(depth / 2), 2, padding='same'))
generator.add(Activation('relu'))
# Out: 28 x 28 x 1 grayscale image [0.0,1.0] per pix
generator.add(Conv2D(1, 5, padding='same'))
generator.add(Activation('sigmoid'))
generator.summary()

dcgan.generator = generator
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200704)            20271104
# _________________________________________________________________
# activation (Activation)      (None, 200704)            0
# _________________________________________________________________
# reshape (Reshape)            (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 28, 28, 128)       131200
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 1)         3201
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 20,405,505
# Trainable params: 20,405,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Określenie rozmiaru warstwy wejściowej

# %%
input_shape = (28, 28, 1)
dcgan.img_rows = 28
dcgan.img_cols = 28
dcgan.channel = 1

# %% [markdown]
# #Utworzenie sieci dla modułu dyskryminatora

# %%
from keras.models import Sequential
discriminator = Sequential()
# In: 28 x 28 x 1, depth = 1
# Out: 14 x 14 x 1, depth=64
discriminator.add(Conv2D(filters=32, kernel_size=5, strides=2, input_shape=input_shape, padding='same'))
discriminator.add(LeakyReLU(alpha=0.2))
discriminator.add(Conv2D(filters=128, kernel_size=5, strides=2, padding='same'))
discriminator.add(LeakyReLU(alpha=0.2))

# Out: 1-dim probability
discriminator.add(Flatten())
discriminator.add(Dense(1))
discriminator.add(Activation('sigmoid'))
discriminator.summary()


dcgan.discriminator = discriminator
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 14, 14, 32)        832
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 7, 128)         102528
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 6273
# _________________________________________________________________
# activation_3 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 109,633
# Trainable params: 109,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ###Określenie optimizera, funkcji celu oraz metryk dla modelu dyskryminacji i modelu przeciwności

# %%
from keras.optimizers import Adam, RMSprop
dcgan.optimizer_for_discriminator_model = RMSprop(lr=0.0002, decay=6e-8)
dcgan.optimizer_for_adversarial_model = RMSprop(lr=0.0001, decay=3e-8)
dcgan.loss_for_discriminator_model = 'binary_crossentropy'
dcgan.loss_for_adversarial_model = 'binary_crossentropy'
dcgan.metrics_for_discriminator_model = ['accuracy']
dcgan.metrics_for_adversarial_model = ['accuracy']

# %% [markdown]
# #Przygotowanie danych treningowych ze zbioru MNIST

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)


import os
# print(os.listdir("./sample_data"))
mnistO = pd.read_csv("./sample_data/mnist_train_small.csv")
#Ekstrakcja obrazów przedstawiających tylko zero
mnist = mnistO[mnistO.iloc[:,0]==0]
mnist = mnist.iloc[:,1:]
mnist = np.array(mnist)/255
print(mnist.shape)

mnist_images_zero = mnist.reshape(mnist.shape[0], 28,28,1)
# mnist_images_zero = mnist
print(mnist_images_zero.shape)
# Out:
# (1962, 784)
# (1962, 28, 28, 1)

# %% [markdown]
# #Ustawienie folderu do zapisu obrazów z generatora

# %%
# %%bash
# pwd
# cd ./gdrive
# pwd
# ls
# cd ./MyDrive
# cd ./'Colab Notebooks'
# pwd
# cd ./gan_zero_colab
# pwd
# ls
# Out:
# /content
# /content/gdrive
# MyDrive
# Shareddrives
# /content/gdrive/MyDrive/Colab Notebooks
# /content/gdrive/MyDrive/Colab Notebooks/gan_zero_colab
# mnist.png

# %%
dcgan.path_to_save_images = '/content/gdrive/MyDrive/Colab Notebooks/gan_zero_colab'

# %% [markdown]
# #Uruchomienie działania GANA

# %%
timer = ElapsedTimer()
dcgan.train(train_X=mnist_images_zero, train_Y=None, train_steps=1000, batch_size=256, save_interval=10, debug=False)
timer.elapsed_time()
# Out:
# 0: [Discriminator loss: 0.683616, acc: 0.550781 | duration: 2.793797 s]  [Generator loss: 0.866167, acc: 0.000000 | duration: 6.817704 s]
# 1: [Discriminator loss: 0.615005, acc: 0.906250 | duration: 2.092321 s]  [Generator loss: 0.964428, acc: 0.000000 | duration: 6.124160 s]
# 2: [Discriminator loss: 0.565456, acc: 0.992188 | duration: 2.035619 s]  [Generator loss: 1.051735, acc: 0.000000 | duration: 6.033581 s]
# 3: [Discriminator loss: 0.523748, acc: 0.984375 | duration: 2.046433 s]  [Generator loss: 1.142406, acc: 0.000000 | duration: 6.062376 s]
# 4: [Discriminator loss: 0.483775, acc: 0.998047 | duration: 2.083710 s]  [Generator loss: 1.225169, acc: 0.000000 | duration: 6.002123 s]
# 5: [Discriminator loss: 0.447298, acc: 1.000000 | duration: 2.110364 s]  [Generator loss: 1.315590, acc: 0.000000 | duration: 6.071213 s]
# 6: [Discriminator loss: 0.414468, acc: 1.000000 | duration: 2.072239 s]  [Generator loss: 1.388444, acc: 0.000000 | duration: 6.088248 s]
# 7: [Discriminator loss: 0.378820, acc: 1.000000 | duration: 2.055792 s]  [Generator loss: 1.466044, acc: 0.000000 | duration: 6.143403 s]
# 8: [Discriminator loss: 0.349663, acc: 1.000000 | duration: 2.033673 s]  [Generator loss: 1.535227, acc: 0.000000 | duration: 6.027588 s]
# 9: [Discriminator loss: 0.325567, acc: 1.000000 | duration: 2.050951 s]  [Generator loss: 1.615864, acc: 0.000000 | duration: 6.023353 s]
# 10: [Discriminator loss: 0.302734, acc: 1.000000 | duration: 2.044147 s]  [Generator loss: 1.669893, acc: 0.000000 | duration: 6.006917 s]
# 11: [Discriminator loss: 0.276949, acc: 1.000000 | duration: 2.109291 s]  [Generator loss: 1.735883, acc: 0.000000 | duration: 6.129124 s]
# 12: [Discriminator loss: 0.260984, acc: 1.000000 | duration: 2.017281 s]  [Generator loss: 1.798938, acc: 0.000000 | duration: 6.010706 s]
# 13: [Discriminator loss: 0.238604, acc: 1.000000 | duration: 2.068105 s]  [Generator loss: 1.860348, acc: 0.000000 | duration: 6.010063 s]
# 14: [Discriminator loss: 0.226619, acc: 1.000000 | duration: 2.047455 s]  [Generator loss: 1.912028, acc: 0.000000 | duration: 6.017387 s]
# 15: [Discriminator loss: 0.211772, acc: 1.000000 | duration: 2.048701 s]  [Generator loss: 1.960654, acc: 0.000000 | duration: 6.042302 s]
# 16: [Discriminator loss: 0.204053, acc: 1.000000 | duration: 2.038793 s]  [Generator loss: 2.002189, acc: 0.000000 | duration: 6.050549 s]
# 17: [Discriminator loss: 0.183449, acc: 1.000000 | duration: 2.044557 s]  [Generator loss: 2.056328, acc: 0.000000 | duration: 6.007952 s]
# 18: [Discriminator loss: 0.175807, acc: 1.000000 | duration: 2.076544 s]  [Generator loss: 2.084897, acc: 0.000000 | duration: 6.195237 s]
# 19: [Discriminator loss: 0.172108, acc: 1.000000 | duration: 2.036703 s]  [Generator loss: 2.101409, acc: 0.000000 | duration: 6.064234 s]
# 20: [Discriminator loss: 0.161870, acc: 1.000000 | duration: 2.076473 s]  [Generator loss: 2.165253, acc: 0.000000 | duration: 6.051183 s]
# 21: [Discriminator loss: 0.153339, acc: 1.000000 | duration: 2.059399 s]  [Generator loss: 2.173769, acc: 0.000000 | duration: 5.980230 s]
# 22: [Discriminator loss: 0.151645, acc: 1.000000 | duration: 2.044289 s]  [Generator loss: 2.194156, acc: 0.000000 | duration: 6.201361 s]
# 23: [Discriminator loss: 0.149208, acc: 1.000000 | duration: 2.075342 s]  [Generator loss: 2.173166, acc: 0.000000 | duration: 6.129712 s]
# 24: [Discriminator loss: 0.141742, acc: 1.000000 | duration: 2.029244 s]  [Generator loss: 2.215758, acc: 0.000000 | duration: 6.141076 s]
# 25: [Discriminator loss: 0.140072, acc: 1.000000 | duration: 2.085356 s]  [Generator loss: 2.179152, acc: 0.000000 | duration: 6.138401 s]
# 26: [Discriminator loss: 0.139976, acc: 1.000000 | duration: 2.026232 s]  [Generator loss: 2.216273, acc: 0.000000 | duration: 6.170855 s]
# 27: [Discriminator loss: 0.141207, acc: 1.000000 | duration: 2.069800 s]  [Generator loss: 2.171603, acc: 0.000000 | duration: 6.002936 s]
# 28: [Discriminator loss: 0.138908, acc: 1.000000 | duration: 2.036146 s]  [Generator loss: 2.227971, acc: 0.000000 | duration: 5.981379 s]
# 29: [Discriminator loss: 0.134342, acc: 1.000000 | duration: 2.058593 s]  [Generator loss: 2.124135, acc: 0.000000 | duration: 5.950957 s]
# 30: [Discriminator loss: 0.138908, acc: 1.000000 | duration: 2.049999 s]  [Generator loss: 2.253963, acc: 0.000000 | duration: 5.901090 s]
# 31: [Discriminator loss: 0.141631, acc: 1.000000 | duration: 2.066903 s]  [Generator loss: 1.997987, acc: 0.000000 | duration: 5.980572 s]
# 32: [Discriminator loss: 0.147350, acc: 1.000000 | duration: 2.071075 s]  [Generator loss: 2.247632, acc: 0.000000 | duration: 6.194970 s]
# 33: [Discriminator loss: 0.150293, acc: 0.998047 | duration: 2.081046 s]  [Generator loss: 1.931759, acc: 0.000000 | duration: 6.137188 s]
# 34: [Discriminator loss: 0.151168, acc: 1.000000 | duration: 2.104947 s]  [Generator loss: 2.089837, acc: 0.000000 | duration: 6.237825 s]
# 35: [Discriminator loss: 0.151836, acc: 1.000000 | duration: 2.141432 s]  [Generator loss: 1.900843, acc: 0.000000 | duration: 5.915948 s]
# 36: [Discriminator loss: 0.161486, acc: 1.000000 | duration: 2.036587 s]  [Generator loss: 2.031530, acc: 0.000000 | duration: 6.084307 s]
# 37: [Discriminator loss: 0.160091, acc: 0.998047 | duration: 2.036318 s]  [Generator loss: 1.776549, acc: 0.000000 | duration: 6.057482 s]
# 38: [Discriminator loss: 0.168482, acc: 1.000000 | duration: 2.061833 s]  [Generator loss: 1.906007, acc: 0.000000 | duration: 6.150757 s]
# 39: [Discriminator loss: 0.168496, acc: 1.000000 | duration: 2.052443 s]  [Generator loss: 1.714888, acc: 0.000000 | duration: 5.980473 s]
# 40: [Discriminator loss: 0.176647, acc: 0.998047 | duration: 2.058488 s]  [Generator loss: 1.861896, acc: 0.000000 | duration: 5.990237 s]
# 41: [Discriminator loss: 0.181781, acc: 0.992188 | duration: 2.034852 s]  [Generator loss: 1.653891, acc: 0.000000 | duration: 5.983434 s]
# 42: [Discriminator loss: 0.186326, acc: 0.998047 | duration: 2.019584 s]  [Generator loss: 1.823830, acc: 0.000000 | duration: 5.967141 s]
# 43: [Discriminator loss: 0.196076, acc: 0.998047 | duration: 2.068051 s]  [Generator loss: 1.463566, acc: 0.000000 | duration: 5.983659 s]
# 44: [Discriminator loss: 0.199829, acc: 1.000000 | duration: 2.056445 s]  [Generator loss: 1.734985, acc: 0.000000 | duration: 5.989681 s]
# 45: [Discriminator loss: 0.210528, acc: 0.988281 | duration: 2.060935 s]  [Generator loss: 1.422629, acc: 0.000000 | duration: 6.014198 s]
# 46: [Discriminator loss: 0.208429, acc: 0.998047 | duration: 2.039579 s]  [Generator loss: 1.615186, acc: 0.000000 | duration: 6.000962 s]
# 47: [Discriminator loss: 0.212109, acc: 0.992188 | duration: 2.061947 s]  [Generator loss: 1.414267, acc: 0.000000 | duration: 6.143143 s]
# 48: [Discriminator loss: 0.213005, acc: 1.000000 | duration: 2.037243 s]  [Generator loss: 1.571356, acc: 0.000000 | duration: 6.154610 s]
# 49: [Discriminator loss: 0.226969, acc: 0.992188 | duration: 2.121258 s]  [Generator loss: 1.332320, acc: 0.000000 | duration: 5.963830 s]
# 50: [Discriminator loss: 0.227003, acc: 1.000000 | duration: 2.046689 s]  [Generator loss: 1.579490, acc: 0.000000 | duration: 6.113475 s]
# 51: [Discriminator loss: 0.239748, acc: 0.990234 | duration: 2.062966 s]  [Generator loss: 1.227467, acc: 0.000000 | duration: 6.047104 s]
# 52: [Discriminator loss: 0.248787, acc: 0.996094 | duration: 2.098407 s]  [Generator loss: 1.476382, acc: 0.000000 | duration: 6.083952 s]
# 53: [Discriminator loss: 0.244453, acc: 0.992188 | duration: 2.040241 s]  [Generator loss: 1.226864, acc: 0.000000 | duration: 6.073712 s]
# 54: [Discriminator loss: 0.249576, acc: 0.996094 | duration: 2.031745 s]  [Generator loss: 1.433722, acc: 0.000000 | duration: 6.219122 s]
# 55: [Discriminator loss: 0.255261, acc: 0.990234 | duration: 2.084375 s]  [Generator loss: 1.187684, acc: 0.000000 | duration: 5.936061 s]
# 56: [Discriminator loss: 0.259608, acc: 0.992188 | duration: 2.048059 s]  [Generator loss: 1.380856, acc: 0.000000 | duration: 6.070197 s]
# 57: [Discriminator loss: 0.260011, acc: 0.996094 | duration: 2.047509 s]  [Generator loss: 1.124458, acc: 0.000000 | duration: 6.047997 s]
# 58: [Discriminator loss: 0.261488, acc: 0.996094 | duration: 2.054040 s]  [Generator loss: 1.367690, acc: 0.000000 | duration: 6.145264 s]
# 59: [Discriminator loss: 0.273424, acc: 0.980469 | duration: 2.105709 s]  [Generator loss: 1.088049, acc: 0.000000 | duration: 5.979367 s]
# 60: [Discriminator loss: 0.269559, acc: 1.000000 | duration: 2.045701 s]  [Generator loss: 1.350726, acc: 0.000000 | duration: 6.009209 s]
# 61: [Discriminator loss: 0.270852, acc: 0.990234 | duration: 2.065216 s]  [Generator loss: 1.143578, acc: 0.000000 | duration: 6.214443 s]
# 62: [Discriminator loss: 0.268311, acc: 0.998047 | duration: 2.035908 s]  [Generator loss: 1.259340, acc: 0.000000 | duration: 6.155522 s]
# 63: [Discriminator loss: 0.258326, acc: 0.996094 | duration: 2.057953 s]  [Generator loss: 1.201748, acc: 0.000000 | duration: 6.023252 s]
# 64: [Discriminator loss: 0.268196, acc: 0.994141 | duration: 2.064586 s]  [Generator loss: 1.225722, acc: 0.000000 | duration: 6.121113 s]
# 65: [Discriminator loss: 0.267312, acc: 0.996094 | duration: 2.030047 s]  [Generator loss: 1.217538, acc: 0.000000 | duration: 6.084429 s]
# 66: [Discriminator loss: 0.258048, acc: 0.990234 | duration: 2.018903 s]  [Generator loss: 1.253527, acc: 0.000000 | duration: 6.177854 s]
# 67: [Discriminator loss: 0.263723, acc: 0.990234 | duration: 2.035913 s]  [Generator loss: 1.179976, acc: 0.000000 | duration: 5.992618 s]
# 68: [Discriminator loss: 0.275016, acc: 0.994141 | duration: 2.058814 s]  [Generator loss: 1.198457, acc: 0.000000 | duration: 6.074134 s]
# 69: [Discriminator loss: 0.264711, acc: 0.998047 | duration: 2.147769 s]  [Generator loss: 1.239206, acc: 0.000000 | duration: 6.107926 s]
# 70: [Discriminator loss: 0.258350, acc: 0.996094 | duration: 2.053607 s]  [Generator loss: 1.232518, acc: 0.000000 | duration: 6.201926 s]
# 71: [Discriminator loss: 0.251826, acc: 0.996094 | duration: 2.047321 s]  [Generator loss: 1.304145, acc: 0.000000 | duration: 6.159906 s]
# 72: [Discriminator loss: 0.257481, acc: 0.988281 | duration: 2.079906 s]  [Generator loss: 1.110320, acc: 0.000000 | duration: 6.129586 s]
# 73: [Discriminator loss: 0.256492, acc: 0.998047 | duration: 2.089605 s]  [Generator loss: 1.456464, acc: 0.000000 | duration: 6.111106 s]
# 74: [Discriminator loss: 0.272057, acc: 0.968750 | duration: 2.036976 s]  [Generator loss: 0.995863, acc: 0.000000 | duration: 5.957340 s]
# 75: [Discriminator loss: 0.280968, acc: 0.998047 | duration: 2.085241 s]  [Generator loss: 1.412825, acc: 0.000000 | duration: 6.131718 s]
# 76: [Discriminator loss: 0.263423, acc: 0.968750 | duration: 2.049950 s]  [Generator loss: 1.148752, acc: 0.000000 | duration: 6.236445 s]
# 77: [Discriminator loss: 0.253452, acc: 0.996094 | duration: 2.053491 s]  [Generator loss: 1.360430, acc: 0.000000 | duration: 6.000415 s]
# 78: [Discriminator loss: 0.253898, acc: 0.982422 | duration: 2.061658 s]  [Generator loss: 1.209644, acc: 0.000000 | duration: 6.046425 s]
# 79: [Discriminator loss: 0.244649, acc: 0.994141 | duration: 2.072595 s]  [Generator loss: 1.409882, acc: 0.000000 | duration: 6.129990 s]
# 80: [Discriminator loss: 0.250803, acc: 0.982422 | duration: 2.071361 s]  [Generator loss: 1.204897, acc: 0.000000 | duration: 6.093729 s]
# 81: [Discriminator loss: 0.245628, acc: 0.994141 | duration: 2.045244 s]  [Generator loss: 1.403526, acc: 0.000000 | duration: 6.151849 s]
# 82: [Discriminator loss: 0.238274, acc: 0.990234 | duration: 2.017105 s]  [Generator loss: 1.250424, acc: 0.000000 | duration: 6.080885 s]
# 83: [Discriminator loss: 0.238410, acc: 0.990234 | duration: 2.116792 s]  [Generator loss: 1.454620, acc: 0.000000 | duration: 6.207732 s]
# 84: [Discriminator loss: 0.229915, acc: 0.986328 | duration: 2.034443 s]  [Generator loss: 1.261243, acc: 0.000000 | duration: 6.044263 s]
# 85: [Discriminator loss: 0.235010, acc: 0.996094 | duration: 2.079881 s]  [Generator loss: 1.504865, acc: 0.000000 | duration: 6.111426 s]
# 86: [Discriminator loss: 0.244516, acc: 0.980469 | duration: 2.019351 s]  [Generator loss: 1.160621, acc: 0.000000 | duration: 6.204120 s]
# 87: [Discriminator loss: 0.236879, acc: 0.998047 | duration: 2.079546 s]  [Generator loss: 1.598671, acc: 0.000000 | duration: 5.992291 s]
# 88: [Discriminator loss: 0.239518, acc: 0.976562 | duration: 2.040175 s]  [Generator loss: 1.181588, acc: 0.000000 | duration: 6.096590 s]
# 89: [Discriminator loss: 0.234432, acc: 0.998047 | duration: 2.124482 s]  [Generator loss: 1.583032, acc: 0.000000 | duration: 5.991198 s]
# 90: [Discriminator loss: 0.218222, acc: 0.994141 | duration: 2.068622 s]  [Generator loss: 1.291284, acc: 0.000000 | duration: 6.158187 s]
# 91: [Discriminator loss: 0.225409, acc: 0.998047 | duration: 2.027014 s]  [Generator loss: 1.545446, acc: 0.000000 | duration: 6.126346 s]
# 92: [Discriminator loss: 0.218468, acc: 0.974609 | duration: 2.051141 s]  [Generator loss: 1.381956, acc: 0.000000 | duration: 6.166674 s]
# 93: [Discriminator loss: 0.223116, acc: 0.992188 | duration: 2.071522 s]  [Generator loss: 1.511498, acc: 0.000000 | duration: 5.960588 s]
# 94: [Discriminator loss: 0.209866, acc: 0.986328 | duration: 2.068677 s]  [Generator loss: 1.472147, acc: 0.000000 | duration: 6.168464 s]
# 95: [Discriminator loss: 0.215501, acc: 0.990234 | duration: 2.082392 s]  [Generator loss: 1.481003, acc: 0.000000 | duration: 6.156149 s]
# 96: [Discriminator loss: 0.206022, acc: 0.992188 | duration: 2.070439 s]  [Generator loss: 1.556275, acc: 0.000000 | duration: 6.130918 s]
# 97: [Discriminator loss: 0.213446, acc: 0.988281 | duration: 2.056279 s]  [Generator loss: 1.402014, acc: 0.000000 | duration: 6.027484 s]
# 98: [Discriminator loss: 0.215201, acc: 0.986328 | duration: 2.150521 s]  [Generator loss: 1.695295, acc: 0.000000 | duration: 5.994143 s]
# 99: [Discriminator loss: 0.208125, acc: 0.990234 | duration: 2.083996 s]  [Generator loss: 1.252989, acc: 0.000000 | duration: 6.003790 s]
# 100: [Discriminator loss: 0.223754, acc: 0.998047 | duration: 2.041416 s]  [Generator loss: 1.881088, acc: 0.000000 | duration: 6.070282 s]
# 101: [Discriminator loss: 0.216546, acc: 0.980469 | duration: 2.025306 s]  [Generator loss: 1.168366, acc: 0.000000 | duration: 6.056818 s]
# 102: [Discriminator loss: 0.237112, acc: 1.000000 | duration: 2.039145 s]  [Generator loss: 1.850592, acc: 0.000000 | duration: 6.002892 s]
# 103: [Discriminator loss: 0.220576, acc: 0.974609 | duration: 2.032024 s]  [Generator loss: 1.290434, acc: 0.000000 | duration: 6.097509 s]
# 104: [Discriminator loss: 0.216770, acc: 0.998047 | duration: 2.037721 s]  [Generator loss: 1.762349, acc: 0.000000 | duration: 6.039340 s]
# 105: [Discriminator loss: 0.210389, acc: 0.978516 | duration: 2.069928 s]  [Generator loss: 1.409701, acc: 0.000000 | duration: 6.058171 s]
# 106: [Discriminator loss: 0.205681, acc: 0.998047 | duration: 2.035903 s]  [Generator loss: 1.781054, acc: 0.000000 | duration: 6.074179 s]
# 107: [Discriminator loss: 0.220643, acc: 0.978516 | duration: 2.066534 s]  [Generator loss: 1.301194, acc: 0.000000 | duration: 6.229352 s]
# 108: [Discriminator loss: 0.219160, acc: 1.000000 | duration: 2.062608 s]  [Generator loss: 1.844615, acc: 0.000000 | duration: 5.934129 s]
# 109: [Discriminator loss: 0.218439, acc: 0.974609 | duration: 2.099621 s]  [Generator loss: 1.351494, acc: 0.000000 | duration: 6.105152 s]
# 110: [Discriminator loss: 0.219742, acc: 0.994141 | duration: 2.066119 s]  [Generator loss: 1.788125, acc: 0.000000 | duration: 6.062774 s]
# 111: [Discriminator loss: 0.208612, acc: 0.984375 | duration: 2.062607 s]  [Generator loss: 1.419901, acc: 0.000000 | duration: 5.933222 s]
# 112: [Discriminator loss: 0.211360, acc: 0.994141 | duration: 2.059922 s]  [Generator loss: 1.794622, acc: 0.000000 | duration: 6.179158 s]
# 113: [Discriminator loss: 0.208472, acc: 0.976562 | duration: 2.071262 s]  [Generator loss: 1.395352, acc: 0.000000 | duration: 6.068953 s]
# 114: [Discriminator loss: 0.210218, acc: 0.996094 | duration: 2.063845 s]  [Generator loss: 1.854142, acc: 0.000000 | duration: 6.118802 s]
# 115: [Discriminator loss: 0.215560, acc: 0.970703 | duration: 2.077743 s]  [Generator loss: 1.319494, acc: 0.000000 | duration: 5.957353 s]
# 116: [Discriminator loss: 0.227154, acc: 0.992188 | duration: 2.045731 s]  [Generator loss: 1.930829, acc: 0.000000 | duration: 6.089699 s]
# 117: [Discriminator loss: 0.229494, acc: 0.962891 | duration: 2.037951 s]  [Generator loss: 1.223489, acc: 0.000000 | duration: 6.095353 s]
# 118: [Discriminator loss: 0.242969, acc: 0.996094 | duration: 2.067433 s]  [Generator loss: 1.952024, acc: 0.000000 | duration: 6.053290 s]
# 119: [Discriminator loss: 0.222245, acc: 0.962891 | duration: 2.075573 s]  [Generator loss: 1.294017, acc: 0.000000 | duration: 6.030226 s]
# 120: [Discriminator loss: 0.235225, acc: 0.996094 | duration: 2.026914 s]  [Generator loss: 1.888289, acc: 0.000000 | duration: 5.956059 s]
# 121: [Discriminator loss: 0.225797, acc: 0.972656 | duration: 2.054862 s]  [Generator loss: 1.253874, acc: 0.000000 | duration: 6.046096 s]
# 122: [Discriminator loss: 0.234307, acc: 0.996094 | duration: 2.044450 s]  [Generator loss: 1.950314, acc: 0.000000 | duration: 5.971943 s]
# 123: [Discriminator loss: 0.246370, acc: 0.943359 | duration: 2.028498 s]  [Generator loss: 1.213233, acc: 0.000000 | duration: 5.978776 s]
# 124: [Discriminator loss: 0.240535, acc: 0.994141 | duration: 2.110049 s]  [Generator loss: 2.026642, acc: 0.000000 | duration: 6.022989 s]
# 125: [Discriminator loss: 0.243292, acc: 0.949219 | duration: 2.007418 s]  [Generator loss: 1.231055, acc: 0.000000 | duration: 5.946712 s]
# 126: [Discriminator loss: 0.242938, acc: 0.994141 | duration: 2.053946 s]  [Generator loss: 1.950920, acc: 0.000000 | duration: 5.982892 s]
# 127: [Discriminator loss: 0.230586, acc: 0.964844 | duration: 2.061314 s]  [Generator loss: 1.347610, acc: 0.000000 | duration: 6.047267 s]
# 128: [Discriminator loss: 0.239450, acc: 0.988281 | duration: 2.058780 s]  [Generator loss: 1.831038, acc: 0.000000 | duration: 6.013443 s]
# 129: [Discriminator loss: 0.229100, acc: 0.974609 | duration: 2.057844 s]  [Generator loss: 1.385781, acc: 0.000000 | duration: 6.039373 s]
# 130: [Discriminator loss: 0.231352, acc: 0.992188 | duration: 2.035169 s]  [Generator loss: 1.817721, acc: 0.000000 | duration: 6.117921 s]
# 131: [Discriminator loss: 0.226343, acc: 0.976562 | duration: 2.063429 s]  [Generator loss: 1.391860, acc: 0.000000 | duration: 6.062197 s]
# 132: [Discriminator loss: 0.240882, acc: 0.986328 | duration: 2.050382 s]  [Generator loss: 1.802217, acc: 0.000000 | duration: 6.144473 s]
# 133: [Discriminator loss: 0.237846, acc: 0.968750 | duration: 2.045051 s]  [Generator loss: 1.244014, acc: 0.000000 | duration: 5.916250 s]
# 134: [Discriminator loss: 0.263175, acc: 0.986328 | duration: 2.080389 s]  [Generator loss: 1.997008, acc: 0.000000 | duration: 6.172883 s]
# 135: [Discriminator loss: 0.270306, acc: 0.953125 | duration: 2.040518 s]  [Generator loss: 0.969995, acc: 0.058594 | duration: 6.052158 s]
# 136: [Discriminator loss: 0.318525, acc: 0.943359 | duration: 2.039232 s]  [Generator loss: 2.087216, acc: 0.000000 | duration: 6.039565 s]
# 137: [Discriminator loss: 0.285447, acc: 0.929688 | duration: 2.002044 s]  [Generator loss: 1.097875, acc: 0.023438 | duration: 5.963970 s]
# 138: [Discriminator loss: 0.284353, acc: 0.972656 | duration: 2.062454 s]  [Generator loss: 1.920292, acc: 0.000000 | duration: 5.930942 s]
# 139: [Discriminator loss: 0.270637, acc: 0.943359 | duration: 2.037990 s]  [Generator loss: 1.212599, acc: 0.003906 | duration: 5.903558 s]
# 140: [Discriminator loss: 0.273337, acc: 0.986328 | duration: 2.066766 s]  [Generator loss: 1.829421, acc: 0.000000 | duration: 5.974677 s]
# 141: [Discriminator loss: 0.270622, acc: 0.958984 | duration: 2.040709 s]  [Generator loss: 1.219799, acc: 0.011719 | duration: 6.175241 s]
# 142: [Discriminator loss: 0.280962, acc: 0.970703 | duration: 2.040751 s]  [Generator loss: 1.828921, acc: 0.000000 | duration: 6.127375 s]
# 143: [Discriminator loss: 0.275272, acc: 0.957031 | duration: 2.049953 s]  [Generator loss: 1.160952, acc: 0.023438 | duration: 5.966397 s]
# 144: [Discriminator loss: 0.291542, acc: 0.974609 | duration: 2.078048 s]  [Generator loss: 1.914412, acc: 0.000000 | duration: 6.089795 s]
# 145: [Discriminator loss: 0.292131, acc: 0.923828 | duration: 2.031549 s]  [Generator loss: 1.073258, acc: 0.015625 | duration: 6.155528 s]
# 146: [Discriminator loss: 0.311180, acc: 0.957031 | duration: 2.052298 s]  [Generator loss: 1.966363, acc: 0.000000 | duration: 6.020611 s]
# 147: [Discriminator loss: 0.310286, acc: 0.923828 | duration: 2.063517 s]  [Generator loss: 0.978597, acc: 0.078125 | duration: 6.035304 s]
# 148: [Discriminator loss: 0.341280, acc: 0.931641 | duration: 2.076892 s]  [Generator loss: 1.956801, acc: 0.000000 | duration: 6.098101 s]
# 149: [Discriminator loss: 0.315998, acc: 0.914062 | duration: 2.129351 s]  [Generator loss: 1.027903, acc: 0.046875 | duration: 5.956655 s]
# 150: [Discriminator loss: 0.318232, acc: 0.949219 | duration: 2.033302 s]  [Generator loss: 1.868785, acc: 0.000000 | duration: 6.101300 s]
# 151: [Discriminator loss: 0.321609, acc: 0.927734 | duration: 2.044736 s]  [Generator loss: 1.079415, acc: 0.054688 | duration: 6.165056 s]
# 152: [Discriminator loss: 0.328168, acc: 0.949219 | duration: 2.068024 s]  [Generator loss: 1.833775, acc: 0.000000 | duration: 5.970432 s]
# 153: [Discriminator loss: 0.332462, acc: 0.908203 | duration: 2.099715 s]  [Generator loss: 1.052792, acc: 0.054688 | duration: 6.086765 s]
# 154: [Discriminator loss: 0.330968, acc: 0.943359 | duration: 2.074529 s]  [Generator loss: 1.838332, acc: 0.000000 | duration: 6.119289 s]
# 155: [Discriminator loss: 0.343049, acc: 0.921875 | duration: 2.026544 s]  [Generator loss: 1.021466, acc: 0.082031 | duration: 6.180421 s]
# 156: [Discriminator loss: 0.337903, acc: 0.935547 | duration: 2.065289 s]  [Generator loss: 1.856535, acc: 0.000000 | duration: 6.036168 s]
# 157: [Discriminator loss: 0.351053, acc: 0.896484 | duration: 2.042307 s]  [Generator loss: 0.957495, acc: 0.132812 | duration: 6.010076 s]
# 158: [Discriminator loss: 0.354836, acc: 0.937500 | duration: 2.104145 s]  [Generator loss: 1.771811, acc: 0.003906 | duration: 5.949599 s]
# 159: [Discriminator loss: 0.358293, acc: 0.908203 | duration: 2.082390 s]  [Generator loss: 0.996748, acc: 0.085938 | duration: 6.103364 s]
# 160: [Discriminator loss: 0.359349, acc: 0.927734 | duration: 2.050964 s]  [Generator loss: 1.733868, acc: 0.003906 | duration: 6.089329 s]
# 161: [Discriminator loss: 0.356619, acc: 0.912109 | duration: 2.057472 s]  [Generator loss: 0.950294, acc: 0.125000 | duration: 6.076097 s]
# 162: [Discriminator loss: 0.383563, acc: 0.906250 | duration: 2.054278 s]  [Generator loss: 1.750176, acc: 0.003906 | duration: 5.921809 s]
# 163: [Discriminator loss: 0.386924, acc: 0.892578 | duration: 2.055091 s]  [Generator loss: 0.909021, acc: 0.148438 | duration: 6.129488 s]
# 164: [Discriminator loss: 0.396819, acc: 0.886719 | duration: 2.037042 s]  [Generator loss: 1.805207, acc: 0.000000 | duration: 6.153557 s]
# 165: [Discriminator loss: 0.392833, acc: 0.863281 | duration: 2.044171 s]  [Generator loss: 0.892479, acc: 0.160156 | duration: 5.936091 s]
# 166: [Discriminator loss: 0.406726, acc: 0.869141 | duration: 2.024954 s]  [Generator loss: 1.794646, acc: 0.007812 | duration: 6.072220 s]
# 167: [Discriminator loss: 0.398751, acc: 0.849609 | duration: 2.038275 s]  [Generator loss: 0.867282, acc: 0.230469 | duration: 6.043420 s]
# 168: [Discriminator loss: 0.416088, acc: 0.869141 | duration: 2.075993 s]  [Generator loss: 1.718819, acc: 0.003906 | duration: 6.033685 s]
# 169: [Discriminator loss: 0.436212, acc: 0.816406 | duration: 2.048459 s]  [Generator loss: 0.862699, acc: 0.234375 | duration: 6.019548 s]
# 170: [Discriminator loss: 0.416134, acc: 0.863281 | duration: 2.057819 s]  [Generator loss: 1.697492, acc: 0.000000 | duration: 6.158095 s]
# 171: [Discriminator loss: 0.407747, acc: 0.847656 | duration: 2.052704 s]  [Generator loss: 0.876558, acc: 0.234375 | duration: 6.193175 s]
# 172: [Discriminator loss: 0.423297, acc: 0.857422 | duration: 2.077180 s]  [Generator loss: 1.663671, acc: 0.000000 | duration: 6.000916 s]
# 173: [Discriminator loss: 0.420625, acc: 0.859375 | duration: 2.100005 s]  [Generator loss: 0.847148, acc: 0.292969 | duration: 6.038610 s]
# 174: [Discriminator loss: 0.435584, acc: 0.855469 | duration: 2.060042 s]  [Generator loss: 1.669383, acc: 0.003906 | duration: 6.140824 s]
# 175: [Discriminator loss: 0.450018, acc: 0.798828 | duration: 2.039827 s]  [Generator loss: 0.794651, acc: 0.304688 | duration: 6.133277 s]
# 176: [Discriminator loss: 0.491467, acc: 0.791016 | duration: 2.044868 s]  [Generator loss: 1.642558, acc: 0.000000 | duration: 5.965700 s]
# 177: [Discriminator loss: 0.473526, acc: 0.777344 | duration: 2.037000 s]  [Generator loss: 0.775870, acc: 0.363281 | duration: 6.067466 s]
# 178: [Discriminator loss: 0.442833, acc: 0.839844 | duration: 2.051298 s]  [Generator loss: 1.618421, acc: 0.011719 | duration: 6.181836 s]
# 179: [Discriminator loss: 0.471446, acc: 0.798828 | duration: 2.009201 s]  [Generator loss: 0.819478, acc: 0.296875 | duration: 6.165123 s]
# 180: [Discriminator loss: 0.462627, acc: 0.826172 | duration: 2.047954 s]  [Generator loss: 1.537144, acc: 0.011719 | duration: 6.025659 s]
# 181: [Discriminator loss: 0.467055, acc: 0.783203 | duration: 2.058913 s]  [Generator loss: 0.778142, acc: 0.406250 | duration: 6.088407 s]
# 182: [Discriminator loss: 0.494807, acc: 0.765625 | duration: 2.057939 s]  [Generator loss: 1.618686, acc: 0.011719 | duration: 6.087303 s]
# 183: [Discriminator loss: 0.497790, acc: 0.744141 | duration: 2.038641 s]  [Generator loss: 0.745592, acc: 0.406250 | duration: 6.081357 s]
# 184: [Discriminator loss: 0.494258, acc: 0.750000 | duration: 2.078515 s]  [Generator loss: 1.567249, acc: 0.015625 | duration: 6.077061 s]
# 185: [Discriminator loss: 0.492873, acc: 0.751953 | duration: 2.060421 s]  [Generator loss: 0.777897, acc: 0.402344 | duration: 6.166797 s]
# 186: [Discriminator loss: 0.500165, acc: 0.769531 | duration: 2.073986 s]  [Generator loss: 1.460052, acc: 0.019531 | duration: 6.058164 s]
# 187: [Discriminator loss: 0.524212, acc: 0.734375 | duration: 2.052107 s]  [Generator loss: 0.730897, acc: 0.460938 | duration: 6.188243 s]
# 188: [Discriminator loss: 0.519505, acc: 0.734375 | duration: 2.068487 s]  [Generator loss: 1.592488, acc: 0.011719 | duration: 6.007310 s]
# 189: [Discriminator loss: 0.537201, acc: 0.675781 | duration: 2.032109 s]  [Generator loss: 0.695585, acc: 0.527344 | duration: 6.091441 s]
# 190: [Discriminator loss: 0.546552, acc: 0.660156 | duration: 2.013010 s]  [Generator loss: 1.622744, acc: 0.011719 | duration: 6.062186 s]
# 191: [Discriminator loss: 0.564486, acc: 0.654297 | duration: 2.033070 s]  [Generator loss: 0.676461, acc: 0.523438 | duration: 5.938085 s]
# 192: [Discriminator loss: 0.540794, acc: 0.714844 | duration: 2.054293 s]  [Generator loss: 1.463145, acc: 0.031250 | duration: 6.165025 s]
# 193: [Discriminator loss: 0.513134, acc: 0.748047 | duration: 2.055985 s]  [Generator loss: 0.827400, acc: 0.332031 | duration: 6.079548 s]
# 194: [Discriminator loss: 0.542211, acc: 0.748047 | duration: 2.059580 s]  [Generator loss: 1.404730, acc: 0.039062 | duration: 6.120975 s]
# 195: [Discriminator loss: 0.549545, acc: 0.736328 | duration: 2.048494 s]  [Generator loss: 0.715707, acc: 0.511719 | duration: 6.131464 s]
# 196: [Discriminator loss: 0.545309, acc: 0.724609 | duration: 2.029049 s]  [Generator loss: 1.399323, acc: 0.050781 | duration: 6.124937 s]
# 197: [Discriminator loss: 0.545531, acc: 0.716797 | duration: 2.029061 s]  [Generator loss: 0.781736, acc: 0.429688 | duration: 6.046034 s]
# 198: [Discriminator loss: 0.545162, acc: 0.734375 | duration: 2.046561 s]  [Generator loss: 1.370420, acc: 0.054688 | duration: 6.096414 s]
# 199: [Discriminator loss: 0.584104, acc: 0.679688 | duration: 2.033057 s]  [Generator loss: 0.734671, acc: 0.527344 | duration: 6.103989 s]
# 200: [Discriminator loss: 0.597062, acc: 0.685547 | duration: 2.053118 s]  [Generator loss: 1.410449, acc: 0.035156 | duration: 6.009005 s]
# 201: [Discriminator loss: 0.554314, acc: 0.703125 | duration: 2.039594 s]  [Generator loss: 0.657371, acc: 0.582031 | duration: 6.110042 s]
# 202: [Discriminator loss: 0.603631, acc: 0.644531 | duration: 2.057325 s]  [Generator loss: 1.541463, acc: 0.027344 | duration: 6.075370 s]
# 203: [Discriminator loss: 0.622794, acc: 0.617188 | duration: 2.072579 s]  [Generator loss: 0.553808, acc: 0.730469 | duration: 6.180525 s]
# 204: [Discriminator loss: 0.634073, acc: 0.583984 | duration: 2.056015 s]  [Generator loss: 1.531710, acc: 0.023438 | duration: 5.979828 s]
# 205: [Discriminator loss: 0.649976, acc: 0.605469 | duration: 2.065310 s]  [Generator loss: 0.608231, acc: 0.636719 | duration: 6.118119 s]
# 206: [Discriminator loss: 0.617655, acc: 0.636719 | duration: 2.056453 s]  [Generator loss: 1.417369, acc: 0.058594 | duration: 6.093651 s]
# 207: [Discriminator loss: 0.599496, acc: 0.642578 | duration: 2.099161 s]  [Generator loss: 0.666689, acc: 0.554688 | duration: 6.164801 s]
# 208: [Discriminator loss: 0.640285, acc: 0.615234 | duration: 2.069871 s]  [Generator loss: 1.305023, acc: 0.078125 | duration: 5.947295 s]
# 209: [Discriminator loss: 0.613416, acc: 0.644531 | duration: 2.073813 s]  [Generator loss: 0.736605, acc: 0.488281 | duration: 6.075004 s]
# 210: [Discriminator loss: 0.602759, acc: 0.693359 | duration: 2.055947 s]  [Generator loss: 1.231532, acc: 0.125000 | duration: 6.013905 s]
# 211: [Discriminator loss: 0.612347, acc: 0.658203 | duration: 2.027817 s]  [Generator loss: 0.748087, acc: 0.472656 | duration: 6.089445 s]
# 212: [Discriminator loss: 0.627187, acc: 0.652344 | duration: 2.012218 s]  [Generator loss: 1.261865, acc: 0.113281 | duration: 6.011224 s]
# 213: [Discriminator loss: 0.633706, acc: 0.621094 | duration: 2.041207 s]  [Generator loss: 0.624605, acc: 0.617188 | duration: 5.936186 s]
# 214: [Discriminator loss: 0.675966, acc: 0.583984 | duration: 2.023156 s]  [Generator loss: 1.292563, acc: 0.085938 | duration: 6.042825 s]
# 215: [Discriminator loss: 0.661785, acc: 0.597656 | duration: 2.034934 s]  [Generator loss: 0.652294, acc: 0.609375 | duration: 5.941128 s]
# 216: [Discriminator loss: 0.661606, acc: 0.609375 | duration: 2.054872 s]  [Generator loss: 1.373463, acc: 0.066406 | duration: 6.043977 s]
# 217: [Discriminator loss: 0.688676, acc: 0.572266 | duration: 2.106059 s]  [Generator loss: 0.587144, acc: 0.664062 | duration: 5.911996 s]
# 218: [Discriminator loss: 0.656404, acc: 0.613281 | duration: 2.075944 s]  [Generator loss: 1.247736, acc: 0.089844 | duration: 6.130588 s]
# 219: [Discriminator loss: 0.683343, acc: 0.582031 | duration: 2.052789 s]  [Generator loss: 0.557421, acc: 0.718750 | duration: 5.941437 s]
# 220: [Discriminator loss: 0.660776, acc: 0.625000 | duration: 2.054442 s]  [Generator loss: 1.205559, acc: 0.101562 | duration: 6.065355 s]
# 221: [Discriminator loss: 0.669546, acc: 0.593750 | duration: 2.069297 s]  [Generator loss: 0.646967, acc: 0.636719 | duration: 6.280002 s]
# 222: [Discriminator loss: 0.644356, acc: 0.640625 | duration: 2.077467 s]  [Generator loss: 1.196873, acc: 0.113281 | duration: 5.964805 s]
# 223: [Discriminator loss: 0.657782, acc: 0.597656 | duration: 2.046549 s]  [Generator loss: 0.589644, acc: 0.695312 | duration: 5.987896 s]
# 224: [Discriminator loss: 0.712409, acc: 0.572266 | duration: 2.022825 s]  [Generator loss: 1.300479, acc: 0.066406 | duration: 6.084498 s]
# 225: [Discriminator loss: 0.677474, acc: 0.587891 | duration: 2.060386 s]  [Generator loss: 0.575446, acc: 0.691406 | duration: 6.103371 s]
# 226: [Discriminator loss: 0.717735, acc: 0.582031 | duration: 2.028889 s]  [Generator loss: 1.341587, acc: 0.089844 | duration: 6.145557 s]
# 227: [Discriminator loss: 0.695275, acc: 0.564453 | duration: 2.106591 s]  [Generator loss: 0.534441, acc: 0.781250 | duration: 5.975127 s]
# 228: [Discriminator loss: 0.743690, acc: 0.570312 | duration: 2.019468 s]  [Generator loss: 1.431571, acc: 0.035156 | duration: 5.981350 s]
# 229: [Discriminator loss: 0.744033, acc: 0.552734 | duration: 2.139409 s]  [Generator loss: 0.529741, acc: 0.750000 | duration: 6.085741 s]
# 230: [Discriminator loss: 0.714369, acc: 0.560547 | duration: 2.017803 s]  [Generator loss: 1.249487, acc: 0.097656 | duration: 6.053264 s]
# 231: [Discriminator loss: 0.700184, acc: 0.539062 | duration: 2.029572 s]  [Generator loss: 0.544189, acc: 0.750000 | duration: 5.961968 s]
# 232: [Discriminator loss: 0.717916, acc: 0.564453 | duration: 2.062436 s]  [Generator loss: 1.006780, acc: 0.210938 | duration: 5.983787 s]
# 233: [Discriminator loss: 0.677941, acc: 0.566406 | duration: 2.023176 s]  [Generator loss: 0.690678, acc: 0.542969 | duration: 6.010012 s]
# 234: [Discriminator loss: 0.704352, acc: 0.562500 | duration: 2.068378 s]  [Generator loss: 0.988167, acc: 0.242188 | duration: 5.973639 s]
# 235: [Discriminator loss: 0.671307, acc: 0.564453 | duration: 2.046045 s]  [Generator loss: 0.627713, acc: 0.640625 | duration: 5.986355 s]
# 236: [Discriminator loss: 0.710408, acc: 0.562500 | duration: 2.052756 s]  [Generator loss: 1.069461, acc: 0.203125 | duration: 6.069483 s]
# 237: [Discriminator loss: 0.715663, acc: 0.546875 | duration: 2.057917 s]  [Generator loss: 0.581759, acc: 0.675781 | duration: 5.989908 s]
# 238: [Discriminator loss: 0.740266, acc: 0.541016 | duration: 2.049905 s]  [Generator loss: 1.090554, acc: 0.160156 | duration: 6.012921 s]
# 239: [Discriminator loss: 0.739664, acc: 0.505859 | duration: 2.051756 s]  [Generator loss: 0.560566, acc: 0.699219 | duration: 6.000531 s]
# 240: [Discriminator loss: 0.737601, acc: 0.546875 | duration: 2.037708 s]  [Generator loss: 1.159984, acc: 0.125000 | duration: 5.956986 s]
# 241: [Discriminator loss: 0.770923, acc: 0.492188 | duration: 2.055632 s]  [Generator loss: 0.471748, acc: 0.871094 | duration: 5.999185 s]
# 242: [Discriminator loss: 0.784696, acc: 0.511719 | duration: 2.055468 s]  [Generator loss: 1.208470, acc: 0.089844 | duration: 6.017130 s]
# 243: [Discriminator loss: 0.809094, acc: 0.496094 | duration: 2.047248 s]  [Generator loss: 0.449465, acc: 0.878906 | duration: 6.084114 s]
# 244: [Discriminator loss: 0.803356, acc: 0.498047 | duration: 2.048934 s]  [Generator loss: 1.191846, acc: 0.132812 | duration: 6.047794 s]
# 245: [Discriminator loss: 0.794192, acc: 0.488281 | duration: 2.051062 s]  [Generator loss: 0.501933, acc: 0.773438 | duration: 5.996732 s]
# 246: [Discriminator loss: 0.788049, acc: 0.498047 | duration: 2.018250 s]  [Generator loss: 1.034346, acc: 0.179688 | duration: 6.064862 s]
# 247: [Discriminator loss: 0.786219, acc: 0.470703 | duration: 2.017544 s]  [Generator loss: 0.567230, acc: 0.734375 | duration: 6.084600 s]
# 248: [Discriminator loss: 0.742500, acc: 0.523438 | duration: 2.062916 s]  [Generator loss: 0.881063, acc: 0.355469 | duration: 6.009660 s]
# 249: [Discriminator loss: 0.757911, acc: 0.474609 | duration: 2.012183 s]  [Generator loss: 0.632511, acc: 0.648438 | duration: 6.105781 s]
# 250: [Discriminator loss: 0.745611, acc: 0.500000 | duration: 2.039555 s]  [Generator loss: 0.882842, acc: 0.304688 | duration: 6.000469 s]
# 251: [Discriminator loss: 0.762642, acc: 0.472656 | duration: 2.129488 s]  [Generator loss: 0.534696, acc: 0.789062 | duration: 6.022514 s]
# 252: [Discriminator loss: 0.790071, acc: 0.486328 | duration: 2.028001 s]  [Generator loss: 1.024766, acc: 0.164062 | duration: 6.024852 s]
# 253: [Discriminator loss: 0.773145, acc: 0.478516 | duration: 2.071837 s]  [Generator loss: 0.507385, acc: 0.796875 | duration: 5.932705 s]
# 254: [Discriminator loss: 0.794933, acc: 0.470703 | duration: 2.051319 s]  [Generator loss: 1.015230, acc: 0.199219 | duration: 6.086141 s]
# 255: [Discriminator loss: 0.820846, acc: 0.437500 | duration: 2.047908 s]  [Generator loss: 0.427970, acc: 0.910156 | duration: 5.914908 s]
# 256: [Discriminator loss: 0.818763, acc: 0.466797 | duration: 2.071415 s]  [Generator loss: 1.025760, acc: 0.167969 | duration: 6.036229 s]
# 257: [Discriminator loss: 0.837002, acc: 0.437500 | duration: 2.066606 s]  [Generator loss: 0.426808, acc: 0.921875 | duration: 6.039227 s]
# 258: [Discriminator loss: 0.846796, acc: 0.458984 | duration: 2.041785 s]  [Generator loss: 1.034051, acc: 0.148438 | duration: 6.176509 s]
# 259: [Discriminator loss: 0.819032, acc: 0.439453 | duration: 2.057794 s]  [Generator loss: 0.489416, acc: 0.871094 | duration: 6.121387 s]
# 260: [Discriminator loss: 0.811549, acc: 0.427734 | duration: 2.078973 s]  [Generator loss: 0.904002, acc: 0.234375 | duration: 5.974649 s]
# 261: [Discriminator loss: 0.829021, acc: 0.412109 | duration: 2.063885 s]  [Generator loss: 0.478994, acc: 0.859375 | duration: 5.936862 s]
# 262: [Discriminator loss: 0.829554, acc: 0.441406 | duration: 2.030072 s]  [Generator loss: 0.928805, acc: 0.207031 | duration: 5.979936 s]
# 263: [Discriminator loss: 0.811791, acc: 0.464844 | duration: 2.026086 s]  [Generator loss: 0.468922, acc: 0.878906 | duration: 5.944074 s]
# 264: [Discriminator loss: 0.827741, acc: 0.419922 | duration: 2.012774 s]  [Generator loss: 0.938195, acc: 0.199219 | duration: 5.879554 s]
# 265: [Discriminator loss: 0.839608, acc: 0.398438 | duration: 2.052129 s]  [Generator loss: 0.471116, acc: 0.890625 | duration: 5.986848 s]
# 266: [Discriminator loss: 0.812436, acc: 0.400391 | duration: 2.029063 s]  [Generator loss: 0.881423, acc: 0.257812 | duration: 5.973727 s]
# 267: [Discriminator loss: 0.830106, acc: 0.396484 | duration: 2.049922 s]  [Generator loss: 0.512378, acc: 0.839844 | duration: 6.079732 s]
# 268: [Discriminator loss: 0.812856, acc: 0.406250 | duration: 2.053124 s]  [Generator loss: 0.856234, acc: 0.250000 | duration: 6.136888 s]
# 269: [Discriminator loss: 0.817413, acc: 0.388672 | duration: 2.027797 s]  [Generator loss: 0.464710, acc: 0.914062 | duration: 6.094137 s]
# 270: [Discriminator loss: 0.838142, acc: 0.378906 | duration: 2.049585 s]  [Generator loss: 0.887061, acc: 0.250000 | duration: 6.093171 s]
# 271: [Discriminator loss: 0.825503, acc: 0.408203 | duration: 2.054229 s]  [Generator loss: 0.434877, acc: 0.933594 | duration: 6.072149 s]
# 272: [Discriminator loss: 0.850038, acc: 0.435547 | duration: 2.037088 s]  [Generator loss: 1.018181, acc: 0.097656 | duration: 6.225703 s]
# 273: [Discriminator loss: 0.858208, acc: 0.416016 | duration: 2.016077 s]  [Generator loss: 0.415796, acc: 0.953125 | duration: 6.193408 s]
# 274: [Discriminator loss: 0.849970, acc: 0.416016 | duration: 2.070867 s]  [Generator loss: 0.926011, acc: 0.160156 | duration: 5.993210 s]
# 275: [Discriminator loss: 0.842305, acc: 0.423828 | duration: 2.047302 s]  [Generator loss: 0.402501, acc: 0.984375 | duration: 6.088026 s]
# 276: [Discriminator loss: 0.835670, acc: 0.417969 | duration: 2.066121 s]  [Generator loss: 0.944417, acc: 0.140625 | duration: 5.981770 s]
# 277: [Discriminator loss: 0.816750, acc: 0.451172 | duration: 2.039732 s]  [Generator loss: 0.463819, acc: 0.949219 | duration: 6.122294 s]
# 278: [Discriminator loss: 0.828546, acc: 0.400391 | duration: 2.069138 s]  [Generator loss: 0.928825, acc: 0.144531 | duration: 6.032019 s]
# 279: [Discriminator loss: 0.830703, acc: 0.441406 | duration: 2.043303 s]  [Generator loss: 0.434932, acc: 0.980469 | duration: 6.145428 s]
# 280: [Discriminator loss: 0.840662, acc: 0.404297 | duration: 2.140619 s]  [Generator loss: 0.943105, acc: 0.105469 | duration: 6.071649 s]
# 281: [Discriminator loss: 0.830974, acc: 0.457031 | duration: 2.106532 s]  [Generator loss: 0.454903, acc: 0.960938 | duration: 6.105039 s]
# 282: [Discriminator loss: 0.843717, acc: 0.386719 | duration: 2.065971 s]  [Generator loss: 0.877313, acc: 0.222656 | duration: 6.158122 s]
# 283: [Discriminator loss: 0.830194, acc: 0.423828 | duration: 2.071458 s]  [Generator loss: 0.422451, acc: 1.000000 | duration: 6.101236 s]
# 284: [Discriminator loss: 0.845748, acc: 0.378906 | duration: 2.052286 s]  [Generator loss: 0.884768, acc: 0.164062 | duration: 5.951695 s]
# 285: [Discriminator loss: 0.823189, acc: 0.419922 | duration: 2.032454 s]  [Generator loss: 0.473430, acc: 0.972656 | duration: 5.944813 s]
# 286: [Discriminator loss: 0.827403, acc: 0.392578 | duration: 2.059416 s]  [Generator loss: 0.923428, acc: 0.105469 | duration: 6.033695 s]
# 287: [Discriminator loss: 0.835164, acc: 0.478516 | duration: 2.023842 s]  [Generator loss: 0.452461, acc: 0.996094 | duration: 6.048694 s]
# 288: [Discriminator loss: 0.815467, acc: 0.373047 | duration: 2.055478 s]  [Generator loss: 0.894341, acc: 0.125000 | duration: 5.915456 s]
# 289: [Discriminator loss: 0.820755, acc: 0.472656 | duration: 2.048284 s]  [Generator loss: 0.450220, acc: 1.000000 | duration: 6.124349 s]
# 290: [Discriminator loss: 0.811381, acc: 0.394531 | duration: 2.067572 s]  [Generator loss: 0.897345, acc: 0.109375 | duration: 6.066958 s]
# 291: [Discriminator loss: 0.813692, acc: 0.494141 | duration: 2.032420 s]  [Generator loss: 0.482801, acc: 0.980469 | duration: 6.066510 s]
# 292: [Discriminator loss: 0.829985, acc: 0.357422 | duration: 2.055061 s]  [Generator loss: 0.901717, acc: 0.093750 | duration: 6.199059 s]
# 293: [Discriminator loss: 0.828568, acc: 0.492188 | duration: 2.044497 s]  [Generator loss: 0.431668, acc: 1.000000 | duration: 5.969507 s]
# 294: [Discriminator loss: 0.832318, acc: 0.378906 | duration: 2.088012 s]  [Generator loss: 0.928051, acc: 0.070312 | duration: 6.171760 s]
# 295: [Discriminator loss: 0.814069, acc: 0.480469 | duration: 2.059508 s]  [Generator loss: 0.455615, acc: 1.000000 | duration: 6.034515 s]
# 296: [Discriminator loss: 0.817253, acc: 0.361328 | duration: 2.087085 s]  [Generator loss: 0.856849, acc: 0.121094 | duration: 6.196264 s]
# 297: [Discriminator loss: 0.815749, acc: 0.470703 | duration: 2.127369 s]  [Generator loss: 0.454025, acc: 1.000000 | duration: 6.068502 s]
# 298: [Discriminator loss: 0.821273, acc: 0.375000 | duration: 2.057810 s]  [Generator loss: 0.932654, acc: 0.031250 | duration: 6.154495 s]
# 299: [Discriminator loss: 0.829679, acc: 0.509766 | duration: 2.036589 s]  [Generator loss: 0.425096, acc: 1.000000 | duration: 5.980884 s]
# 300: [Discriminator loss: 0.830959, acc: 0.380859 | duration: 2.063945 s]  [Generator loss: 0.927819, acc: 0.046875 | duration: 6.012913 s]
# 301: [Discriminator loss: 0.811921, acc: 0.503906 | duration: 2.078131 s]  [Generator loss: 0.436479, acc: 1.000000 | duration: 6.193011 s]
# 302: [Discriminator loss: 0.831883, acc: 0.365234 | duration: 2.082309 s]  [Generator loss: 0.916406, acc: 0.027344 | duration: 6.114725 s]
# 303: [Discriminator loss: 0.804533, acc: 0.515625 | duration: 2.119173 s]  [Generator loss: 0.485807, acc: 0.996094 | duration: 6.108099 s]
# 304: [Discriminator loss: 0.802862, acc: 0.363281 | duration: 2.024801 s]  [Generator loss: 0.868503, acc: 0.054688 | duration: 6.137349 s]
# 305: [Discriminator loss: 0.800179, acc: 0.513672 | duration: 2.069089 s]  [Generator loss: 0.517965, acc: 0.976562 | duration: 5.962413 s]
# 306: [Discriminator loss: 0.796339, acc: 0.306641 | duration: 2.050877 s]  [Generator loss: 0.825924, acc: 0.125000 | duration: 6.116767 s]
# 307: [Discriminator loss: 0.785948, acc: 0.496094 | duration: 2.112708 s]  [Generator loss: 0.515317, acc: 0.972656 | duration: 5.979441 s]
# 308: [Discriminator loss: 0.808792, acc: 0.312500 | duration: 2.061163 s]  [Generator loss: 0.894142, acc: 0.046875 | duration: 6.014459 s]
# 309: [Discriminator loss: 0.831761, acc: 0.486328 | duration: 2.153243 s]  [Generator loss: 0.427442, acc: 1.000000 | duration: 6.031982 s]
# 310: [Discriminator loss: 0.820321, acc: 0.419922 | duration: 2.035627 s]  [Generator loss: 1.035644, acc: 0.019531 | duration: 5.971915 s]
# 311: [Discriminator loss: 0.833375, acc: 0.501953 | duration: 2.048929 s]  [Generator loss: 0.434490, acc: 1.000000 | duration: 6.070524 s]
# 312: [Discriminator loss: 0.820011, acc: 0.398438 | duration: 2.038027 s]  [Generator loss: 0.977173, acc: 0.011719 | duration: 6.002082 s]
# 313: [Discriminator loss: 0.820944, acc: 0.511719 | duration: 2.039093 s]  [Generator loss: 0.494796, acc: 0.992188 | duration: 6.046408 s]
# 314: [Discriminator loss: 0.810400, acc: 0.347656 | duration: 2.079098 s]  [Generator loss: 0.873670, acc: 0.058594 | duration: 6.157176 s]
# 315: [Discriminator loss: 0.792423, acc: 0.509766 | duration: 2.091290 s]  [Generator loss: 0.483604, acc: 0.988281 | duration: 5.989827 s]
# 316: [Discriminator loss: 0.799214, acc: 0.341797 | duration: 2.073230 s]  [Generator loss: 0.875836, acc: 0.082031 | duration: 6.186407 s]
# 317: [Discriminator loss: 0.801959, acc: 0.494141 | duration: 2.045621 s]  [Generator loss: 0.521736, acc: 0.964844 | duration: 6.038908 s]
# 318: [Discriminator loss: 0.778023, acc: 0.398438 | duration: 2.055770 s]  [Generator loss: 0.929564, acc: 0.019531 | duration: 6.171317 s]
# 319: [Discriminator loss: 0.782528, acc: 0.507812 | duration: 2.121141 s]  [Generator loss: 0.505270, acc: 0.984375 | duration: 5.979814 s]
# 320: [Discriminator loss: 0.790568, acc: 0.363281 | duration: 2.094736 s]  [Generator loss: 0.898970, acc: 0.050781 | duration: 6.054139 s]
# 321: [Discriminator loss: 0.794029, acc: 0.484375 | duration: 2.064427 s]  [Generator loss: 0.489772, acc: 0.980469 | duration: 5.939645 s]
# 322: [Discriminator loss: 0.802612, acc: 0.351562 | duration: 2.039986 s]  [Generator loss: 0.918172, acc: 0.042969 | duration: 6.036095 s]
# 323: [Discriminator loss: 0.782720, acc: 0.519531 | duration: 2.060329 s]  [Generator loss: 0.469558, acc: 0.972656 | duration: 6.140432 s]
# 324: [Discriminator loss: 0.807250, acc: 0.382812 | duration: 2.054160 s]  [Generator loss: 0.970841, acc: 0.007812 | duration: 6.117123 s]
# 325: [Discriminator loss: 0.805632, acc: 0.501953 | duration: 2.044606 s]  [Generator loss: 0.475724, acc: 0.972656 | duration: 6.070165 s]
# 326: [Discriminator loss: 0.779026, acc: 0.421875 | duration: 2.020911 s]  [Generator loss: 0.979413, acc: 0.007812 | duration: 5.979471 s]
# 327: [Discriminator loss: 0.792730, acc: 0.496094 | duration: 2.050802 s]  [Generator loss: 0.492836, acc: 0.976562 | duration: 6.193918 s]
# 328: [Discriminator loss: 0.785051, acc: 0.410156 | duration: 2.049002 s]  [Generator loss: 0.923959, acc: 0.042969 | duration: 5.949177 s]
# 329: [Discriminator loss: 0.778969, acc: 0.517578 | duration: 2.109811 s]  [Generator loss: 0.531930, acc: 0.933594 | duration: 6.005647 s]
# 330: [Discriminator loss: 0.772199, acc: 0.378906 | duration: 2.070541 s]  [Generator loss: 0.898452, acc: 0.089844 | duration: 6.021059 s]
# 331: [Discriminator loss: 0.773999, acc: 0.492188 | duration: 2.158240 s]  [Generator loss: 0.513907, acc: 0.933594 | duration: 6.057351 s]
# 332: [Discriminator loss: 0.770824, acc: 0.402344 | duration: 2.048344 s]  [Generator loss: 0.913542, acc: 0.062500 | duration: 5.988552 s]
# 333: [Discriminator loss: 0.770329, acc: 0.492188 | duration: 2.085827 s]  [Generator loss: 0.504127, acc: 0.937500 | duration: 5.966359 s]
# 334: [Discriminator loss: 0.777415, acc: 0.392578 | duration: 2.112214 s]  [Generator loss: 0.916691, acc: 0.058594 | duration: 6.041409 s]
# 335: [Discriminator loss: 0.759465, acc: 0.517578 | duration: 2.055075 s]  [Generator loss: 0.515766, acc: 0.929688 | duration: 6.021037 s]
# 336: [Discriminator loss: 0.777060, acc: 0.398438 | duration: 2.074898 s]  [Generator loss: 0.934440, acc: 0.070312 | duration: 5.990230 s]
# 337: [Discriminator loss: 0.768448, acc: 0.513672 | duration: 2.098653 s]  [Generator loss: 0.508596, acc: 0.917969 | duration: 6.021069 s]
# 338: [Discriminator loss: 0.772884, acc: 0.410156 | duration: 2.068218 s]  [Generator loss: 0.944633, acc: 0.039062 | duration: 6.113937 s]
# 339: [Discriminator loss: 0.757911, acc: 0.503906 | duration: 2.141495 s]  [Generator loss: 0.504013, acc: 0.957031 | duration: 6.049047 s]
# 340: [Discriminator loss: 0.767905, acc: 0.427734 | duration: 2.084445 s]  [Generator loss: 0.947354, acc: 0.082031 | duration: 6.134638 s]
# 341: [Discriminator loss: 0.774893, acc: 0.496094 | duration: 2.056439 s]  [Generator loss: 0.480768, acc: 0.945312 | duration: 6.163415 s]
# 342: [Discriminator loss: 0.780419, acc: 0.410156 | duration: 2.139535 s]  [Generator loss: 0.981667, acc: 0.066406 | duration: 6.055400 s]
# ...
# 886: [Discriminator loss: 0.682007, acc: 0.583984 | duration: 2.096741 s]  [Generator loss: 0.666358, acc: 0.746094 | duration: 6.038425 s]
# 887: [Discriminator loss: 0.677241, acc: 0.572266 | duration: 2.200782 s]  [Generator loss: 0.768129, acc: 0.046875 | duration: 6.170005 s]
# 888: [Discriminator loss: 0.682307, acc: 0.570312 | duration: 2.142509 s]  [Generator loss: 0.668657, acc: 0.738281 | duration: 6.108414 s]
# 889: [Discriminator loss: 0.675844, acc: 0.582031 | duration: 2.063801 s]  [Generator loss: 0.803908, acc: 0.000000 | duration: 6.036869 s]
# 890: [Discriminator loss: 0.681737, acc: 0.519531 | duration: 2.060849 s]  [Generator loss: 0.638453, acc: 0.859375 | duration: 6.040747 s]
# 891: [Discriminator loss: 0.677828, acc: 0.558594 | duration: 2.099277 s]  [Generator loss: 0.802876, acc: 0.011719 | duration: 6.109586 s]
# 892: [Discriminator loss: 0.683642, acc: 0.531250 | duration: 2.091694 s]  [Generator loss: 0.629022, acc: 0.917969 | duration: 6.130591 s]
# 893: [Discriminator loss: 0.681915, acc: 0.535156 | duration: 2.094462 s]  [Generator loss: 0.799670, acc: 0.007812 | duration: 6.121663 s]
# 894: [Discriminator loss: 0.679293, acc: 0.529297 | duration: 2.098694 s]  [Generator loss: 0.646814, acc: 0.824219 | duration: 6.169116 s]
# 895: [Discriminator loss: 0.681911, acc: 0.548828 | duration: 2.119926 s]  [Generator loss: 0.799108, acc: 0.019531 | duration: 6.028353 s]
# 896: [Discriminator loss: 0.680409, acc: 0.550781 | duration: 2.099010 s]  [Generator loss: 0.641612, acc: 0.886719 | duration: 6.118885 s]
# 897: [Discriminator loss: 0.681645, acc: 0.554688 | duration: 2.075097 s]  [Generator loss: 0.793452, acc: 0.031250 | duration: 6.088590 s]
# 898: [Discriminator loss: 0.683699, acc: 0.535156 | duration: 2.162479 s]  [Generator loss: 0.656408, acc: 0.800781 | duration: 6.120162 s]
# 899: [Discriminator loss: 0.680703, acc: 0.554688 | duration: 2.106421 s]  [Generator loss: 0.729089, acc: 0.253906 | duration: 6.046124 s]
# 900: [Discriminator loss: 0.677243, acc: 0.638672 | duration: 2.120932 s]  [Generator loss: 0.695629, acc: 0.445312 | duration: 6.047462 s]
# 901: [Discriminator loss: 0.676069, acc: 0.650391 | duration: 2.078875 s]  [Generator loss: 0.746279, acc: 0.156250 | duration: 6.094429 s]
# 902: [Discriminator loss: 0.680702, acc: 0.578125 | duration: 2.104833 s]  [Generator loss: 0.675936, acc: 0.574219 | duration: 6.043586 s]
# 903: [Discriminator loss: 0.679362, acc: 0.595703 | duration: 2.065741 s]  [Generator loss: 0.735720, acc: 0.289062 | duration: 6.072884 s]
# 904: [Discriminator loss: 0.685838, acc: 0.542969 | duration: 2.055014 s]  [Generator loss: 0.658008, acc: 0.796875 | duration: 6.030299 s]
# 905: [Discriminator loss: 0.684956, acc: 0.556641 | duration: 2.117913 s]  [Generator loss: 0.835037, acc: 0.007812 | duration: 5.997298 s]
# 906: [Discriminator loss: 0.688068, acc: 0.515625 | duration: 2.096602 s]  [Generator loss: 0.590221, acc: 0.992188 | duration: 6.083157 s]
# 907: [Discriminator loss: 0.690193, acc: 0.496094 | duration: 2.068724 s]  [Generator loss: 0.814178, acc: 0.003906 | duration: 6.017336 s]
# 908: [Discriminator loss: 0.684296, acc: 0.525391 | duration: 2.103878 s]  [Generator loss: 0.619349, acc: 0.941406 | duration: 6.165749 s]
# 909: [Discriminator loss: 0.682261, acc: 0.519531 | duration: 2.145124 s]  [Generator loss: 0.768786, acc: 0.046875 | duration: 6.034035 s]
# 910: [Discriminator loss: 0.682963, acc: 0.546875 | duration: 2.092933 s]  [Generator loss: 0.633858, acc: 0.941406 | duration: 6.026667 s]
# 911: [Discriminator loss: 0.685931, acc: 0.525391 | duration: 2.109823 s]  [Generator loss: 0.783538, acc: 0.027344 | duration: 6.077717 s]
# 912: [Discriminator loss: 0.684299, acc: 0.533203 | duration: 2.163021 s]  [Generator loss: 0.631820, acc: 0.925781 | duration: 6.083262 s]
# 913: [Discriminator loss: 0.684960, acc: 0.525391 | duration: 2.082545 s]  [Generator loss: 0.764575, acc: 0.019531 | duration: 6.019198 s]
# 914: [Discriminator loss: 0.682279, acc: 0.560547 | duration: 2.115081 s]  [Generator loss: 0.658520, acc: 0.800781 | duration: 6.045452 s]
# 915: [Discriminator loss: 0.683709, acc: 0.544922 | duration: 2.075394 s]  [Generator loss: 0.802682, acc: 0.000000 | duration: 6.000296 s]
# 916: [Discriminator loss: 0.684623, acc: 0.529297 | duration: 2.262674 s]  [Generator loss: 0.627951, acc: 0.957031 | duration: 6.052031 s]
# 917: [Discriminator loss: 0.686485, acc: 0.511719 | duration: 2.084122 s]  [Generator loss: 0.787632, acc: 0.000000 | duration: 6.047220 s]
# 918: [Discriminator loss: 0.684429, acc: 0.517578 | duration: 2.102455 s]  [Generator loss: 0.671751, acc: 0.746094 | duration: 5.988738 s]
# 919: [Discriminator loss: 0.686826, acc: 0.529297 | duration: 2.074690 s]  [Generator loss: 0.775319, acc: 0.011719 | duration: 6.009887 s]
# 920: [Discriminator loss: 0.685416, acc: 0.531250 | duration: 2.082464 s]  [Generator loss: 0.629499, acc: 0.945312 | duration: 6.060782 s]
# 921: [Discriminator loss: 0.688003, acc: 0.501953 | duration: 2.085759 s]  [Generator loss: 0.791334, acc: 0.015625 | duration: 6.017847 s]
# 922: [Discriminator loss: 0.686350, acc: 0.531250 | duration: 2.065098 s]  [Generator loss: 0.638908, acc: 0.929688 | duration: 6.044974 s]
# 923: [Discriminator loss: 0.685300, acc: 0.509766 | duration: 2.097031 s]  [Generator loss: 0.790492, acc: 0.023438 | duration: 6.112534 s]
# 924: [Discriminator loss: 0.684045, acc: 0.523438 | duration: 2.082623 s]  [Generator loss: 0.638136, acc: 0.945312 | duration: 6.028633 s]
# 925: [Discriminator loss: 0.687824, acc: 0.507812 | duration: 2.087661 s]  [Generator loss: 0.780977, acc: 0.007812 | duration: 6.029034 s]
# 926: [Discriminator loss: 0.689348, acc: 0.523438 | duration: 2.081959 s]  [Generator loss: 0.660201, acc: 0.851562 | duration: 6.050968 s]
# 927: [Discriminator loss: 0.681842, acc: 0.558594 | duration: 2.122056 s]  [Generator loss: 0.739112, acc: 0.117188 | duration: 6.026628 s]
# 928: [Discriminator loss: 0.683147, acc: 0.585938 | duration: 2.101346 s]  [Generator loss: 0.695026, acc: 0.468750 | duration: 6.149652 s]
# 929: [Discriminator loss: 0.680246, acc: 0.632812 | duration: 2.136026 s]  [Generator loss: 0.735184, acc: 0.175781 | duration: 6.064879 s]
# 930: [Discriminator loss: 0.687171, acc: 0.589844 | duration: 2.051749 s]  [Generator loss: 0.676607, acc: 0.671875 | duration: 6.184530 s]
# 931: [Discriminator loss: 0.687124, acc: 0.558594 | duration: 2.117749 s]  [Generator loss: 0.739427, acc: 0.128906 | duration: 6.021412 s]
# 932: [Discriminator loss: 0.682520, acc: 0.578125 | duration: 2.079670 s]  [Generator loss: 0.657104, acc: 0.832031 | duration: 6.070649 s]
# 933: [Discriminator loss: 0.686981, acc: 0.525391 | duration: 2.045212 s]  [Generator loss: 0.797727, acc: 0.019531 | duration: 6.118160 s]
# 934: [Discriminator loss: 0.692567, acc: 0.521484 | duration: 2.076590 s]  [Generator loss: 0.590491, acc: 0.996094 | duration: 6.026381 s]
# 935: [Discriminator loss: 0.692497, acc: 0.496094 | duration: 2.120982 s]  [Generator loss: 0.813821, acc: 0.019531 | duration: 6.124450 s]
# 936: [Discriminator loss: 0.692012, acc: 0.519531 | duration: 2.057639 s]  [Generator loss: 0.622878, acc: 0.957031 | duration: 6.006362 s]
# 937: [Discriminator loss: 0.693535, acc: 0.490234 | duration: 2.079796 s]  [Generator loss: 0.764326, acc: 0.054688 | duration: 6.147987 s]
# 938: [Discriminator loss: 0.684234, acc: 0.585938 | duration: 2.068201 s]  [Generator loss: 0.662627, acc: 0.785156 | duration: 6.054831 s]
# 939: [Discriminator loss: 0.685801, acc: 0.531250 | duration: 2.081089 s]  [Generator loss: 0.741644, acc: 0.148438 | duration: 6.069579 s]
# 940: [Discriminator loss: 0.689883, acc: 0.550781 | duration: 2.047101 s]  [Generator loss: 0.624463, acc: 0.980469 | duration: 6.005860 s]
# 941: [Discriminator loss: 0.688842, acc: 0.503906 | duration: 2.061633 s]  [Generator loss: 0.762941, acc: 0.054688 | duration: 6.075750 s]
# 942: [Discriminator loss: 0.690702, acc: 0.541016 | duration: 2.092000 s]  [Generator loss: 0.645582, acc: 0.921875 | duration: 6.087292 s]
# 943: [Discriminator loss: 0.687331, acc: 0.511719 | duration: 2.091116 s]  [Generator loss: 0.735658, acc: 0.128906 | duration: 6.109021 s]
# 944: [Discriminator loss: 0.688338, acc: 0.554688 | duration: 2.092957 s]  [Generator loss: 0.657674, acc: 0.839844 | duration: 6.089584 s]
# 945: [Discriminator loss: 0.686732, acc: 0.535156 | duration: 2.368905 s]  [Generator loss: 0.771915, acc: 0.058594 | duration: 6.003530 s]
# 946: [Discriminator loss: 0.690426, acc: 0.509766 | duration: 2.079116 s]  [Generator loss: 0.633210, acc: 0.937500 | duration: 6.055646 s]
# 947: [Discriminator loss: 0.688335, acc: 0.505859 | duration: 2.184554 s]  [Generator loss: 0.770688, acc: 0.035156 | duration: 6.094473 s]
# 948: [Discriminator loss: 0.689281, acc: 0.544922 | duration: 2.135632 s]  [Generator loss: 0.641311, acc: 0.914062 | duration: 6.058352 s]
# 949: [Discriminator loss: 0.693447, acc: 0.509766 | duration: 2.104925 s]  [Generator loss: 0.793935, acc: 0.000000 | duration: 6.098686 s]
# 950: [Discriminator loss: 0.692994, acc: 0.537109 | duration: 2.071270 s]  [Generator loss: 0.610143, acc: 0.992188 | duration: 6.073246 s]
# 951: [Discriminator loss: 0.694110, acc: 0.492188 | duration: 2.101451 s]  [Generator loss: 0.781984, acc: 0.003906 | duration: 6.034846 s]
# 952: [Discriminator loss: 0.695993, acc: 0.515625 | duration: 2.153281 s]  [Generator loss: 0.605924, acc: 1.000000 | duration: 6.160921 s]
# 953: [Discriminator loss: 0.695144, acc: 0.494141 | duration: 2.076530 s]  [Generator loss: 0.767378, acc: 0.035156 | duration: 6.042076 s]
# 954: [Discriminator loss: 0.691477, acc: 0.511719 | duration: 2.071864 s]  [Generator loss: 0.621428, acc: 0.988281 | duration: 6.019177 s]
# 955: [Discriminator loss: 0.692273, acc: 0.498047 | duration: 2.119418 s]  [Generator loss: 0.750957, acc: 0.097656 | duration: 6.074765 s]
# 956: [Discriminator loss: 0.692374, acc: 0.537109 | duration: 2.072883 s]  [Generator loss: 0.682609, acc: 0.644531 | duration: 6.040886 s]
# 957: [Discriminator loss: 0.690444, acc: 0.519531 | duration: 2.147891 s]  [Generator loss: 0.713383, acc: 0.277344 | duration: 6.139035 s]
# 958: [Discriminator loss: 0.694001, acc: 0.503906 | duration: 2.099337 s]  [Generator loss: 0.691522, acc: 0.492188 | duration: 6.090386 s]
# 959: [Discriminator loss: 0.689532, acc: 0.527344 | duration: 2.100455 s]  [Generator loss: 0.687402, acc: 0.554688 | duration: 6.132701 s]
# 960: [Discriminator loss: 0.690064, acc: 0.542969 | duration: 2.054993 s]  [Generator loss: 0.727424, acc: 0.250000 | duration: 6.031966 s]
# 961: [Discriminator loss: 0.694583, acc: 0.525391 | duration: 2.085714 s]  [Generator loss: 0.660830, acc: 0.789062 | duration: 6.014305 s]
# 962: [Discriminator loss: 0.692254, acc: 0.503906 | duration: 2.059025 s]  [Generator loss: 0.722298, acc: 0.199219 | duration: 6.068570 s]
# 963: [Discriminator loss: 0.688984, acc: 0.582031 | duration: 2.060055 s]  [Generator loss: 0.643573, acc: 0.894531 | duration: 6.080060 s]
# 964: [Discriminator loss: 0.694352, acc: 0.505859 | duration: 2.047489 s]  [Generator loss: 0.783015, acc: 0.015625 | duration: 6.012388 s]
# 965: [Discriminator loss: 0.695672, acc: 0.505859 | duration: 2.122607 s]  [Generator loss: 0.584589, acc: 1.000000 | duration: 6.092153 s]
# 966: [Discriminator loss: 0.700583, acc: 0.498047 | duration: 2.080184 s]  [Generator loss: 0.801970, acc: 0.015625 | duration: 6.255324 s]
# 967: [Discriminator loss: 0.698181, acc: 0.501953 | duration: 2.097600 s]  [Generator loss: 0.606505, acc: 0.988281 | duration: 6.099800 s]
# 968: [Discriminator loss: 0.695129, acc: 0.496094 | duration: 2.115511 s]  [Generator loss: 0.766914, acc: 0.023438 | duration: 6.068084 s]
# 969: [Discriminator loss: 0.693350, acc: 0.523438 | duration: 2.058976 s]  [Generator loss: 0.654075, acc: 0.871094 | duration: 6.056749 s]
# 970: [Discriminator loss: 0.693172, acc: 0.480469 | duration: 2.076243 s]  [Generator loss: 0.722809, acc: 0.187500 | duration: 6.049738 s]
# 971: [Discriminator loss: 0.692892, acc: 0.517578 | duration: 2.101700 s]  [Generator loss: 0.668708, acc: 0.800781 | duration: 6.041236 s]
# 972: [Discriminator loss: 0.694683, acc: 0.468750 | duration: 2.072274 s]  [Generator loss: 0.692613, acc: 0.492188 | duration: 6.129151 s]
# 973: [Discriminator loss: 0.691967, acc: 0.539062 | duration: 2.043914 s]  [Generator loss: 0.650631, acc: 0.882812 | duration: 6.075557 s]
# 974: [Discriminator loss: 0.693933, acc: 0.492188 | duration: 2.141158 s]  [Generator loss: 0.738004, acc: 0.082031 | duration: 6.089926 s]
# 975: [Discriminator loss: 0.690425, acc: 0.558594 | duration: 2.071776 s]  [Generator loss: 0.672476, acc: 0.746094 | duration: 5.973420 s]
# 976: [Discriminator loss: 0.692026, acc: 0.517578 | duration: 2.075482 s]  [Generator loss: 0.683148, acc: 0.593750 | duration: 6.120793 s]
# 977: [Discriminator loss: 0.696496, acc: 0.486328 | duration: 2.060952 s]  [Generator loss: 0.713333, acc: 0.312500 | duration: 6.012465 s]
# 978: [Discriminator loss: 0.692010, acc: 0.509766 | duration: 2.081809 s]  [Generator loss: 0.623220, acc: 0.976562 | duration: 6.095437 s]
# 979: [Discriminator loss: 0.698381, acc: 0.503906 | duration: 2.043169 s]  [Generator loss: 0.790418, acc: 0.000000 | duration: 5.966618 s]
# 980: [Discriminator loss: 0.700105, acc: 0.509766 | duration: 2.063214 s]  [Generator loss: 0.589985, acc: 1.000000 | duration: 6.079350 s]
# 981: [Discriminator loss: 0.698176, acc: 0.500000 | duration: 2.173147 s]  [Generator loss: 0.794872, acc: 0.000000 | duration: 6.073974 s]
# 982: [Discriminator loss: 0.697578, acc: 0.509766 | duration: 2.040349 s]  [Generator loss: 0.596135, acc: 1.000000 | duration: 6.110558 s]
# 983: [Discriminator loss: 0.700680, acc: 0.500000 | duration: 2.075908 s]  [Generator loss: 0.747573, acc: 0.058594 | duration: 6.167269 s]
# 984: [Discriminator loss: 0.695357, acc: 0.542969 | duration: 2.038713 s]  [Generator loss: 0.664220, acc: 0.859375 | duration: 6.037835 s]
# 985: [Discriminator loss: 0.693182, acc: 0.480469 | duration: 2.025877 s]  [Generator loss: 0.724082, acc: 0.210938 | duration: 6.047777 s]
# 986: [Discriminator loss: 0.695276, acc: 0.501953 | duration: 2.063740 s]  [Generator loss: 0.647745, acc: 0.945312 | duration: 5.981967 s]
# 987: [Discriminator loss: 0.693367, acc: 0.496094 | duration: 2.037951 s]  [Generator loss: 0.716974, acc: 0.246094 | duration: 6.117410 s]
# 988: [Discriminator loss: 0.690273, acc: 0.542969 | duration: 2.080877 s]  [Generator loss: 0.669186, acc: 0.718750 | duration: 6.300857 s]
# 989: [Discriminator loss: 0.694574, acc: 0.470703 | duration: 2.074532 s]  [Generator loss: 0.677562, acc: 0.664062 | duration: 6.056868 s]
# 990: [Discriminator loss: 0.693174, acc: 0.488281 | duration: 2.073241 s]  [Generator loss: 0.680613, acc: 0.644531 | duration: 5.996093 s]
# 991: [Discriminator loss: 0.692025, acc: 0.486328 | duration: 2.134929 s]  [Generator loss: 0.714141, acc: 0.316406 | duration: 6.122616 s]
# 992: [Discriminator loss: 0.692904, acc: 0.503906 | duration: 2.059902 s]  [Generator loss: 0.635975, acc: 0.949219 | duration: 5.987092 s]
# 993: [Discriminator loss: 0.694880, acc: 0.492188 | duration: 2.092482 s]  [Generator loss: 0.784923, acc: 0.003906 | duration: 6.167228 s]
# 994: [Discriminator loss: 0.699425, acc: 0.523438 | duration: 2.062921 s]  [Generator loss: 0.575978, acc: 1.000000 | duration: 6.009700 s]
# 995: [Discriminator loss: 0.702398, acc: 0.498047 | duration: 2.077589 s]  [Generator loss: 0.794979, acc: 0.003906 | duration: 6.186669 s]
# 996: [Discriminator loss: 0.698415, acc: 0.527344 | duration: 2.072938 s]  [Generator loss: 0.597146, acc: 0.992188 | duration: 5.959682 s]
# 997: [Discriminator loss: 0.699550, acc: 0.498047 | duration: 2.095768 s]  [Generator loss: 0.755228, acc: 0.019531 | duration: 6.135422 s]
# 998: [Discriminator loss: 0.695419, acc: 0.537109 | duration: 2.088425 s]  [Generator loss: 0.633512, acc: 0.980469 | duration: 6.039395 s]
# 999: [Discriminator loss: 0.693381, acc: 0.494141 | duration: 2.058261 s]  [Generator loss: 0.701194, acc: 0.449219 | duration: 6.119200 s]
# Elapsed: 2.319472965863016 hr

# %% [markdown]
# #Wyświetlenie wygenerowanych obrazów

# %%
dcgan.plot_images(fake=True)

# %% [markdown]
# Slider

# %%
import glob
list_generated_images = list()
for file_name in glob.iglob(dcgan.path_to_save_images + '/*.png', recursive=True):
  list_generated_images.append(file_name)

# %%
def display_images(directory, index):
  from keras.preprocessing import image
  # print('directory=',directory)
  fnames = [os.path.join(directory, fname) for fname in os.listdir(directory)]
  fnames = list(filter(lambda k: '.png' in k, fnames))
  img_path = fnames[index]
  print('img_path= ', img_path)
  img = image.load_img(img_path)
  plt.figure(figsize=(10, 10))
  plt.grid(b=None)
  plt.imshow(img)

# %%
index = 61 #@param { type:'slider', min:0, max:99, step:1}
display_images(dcgan.path_to_save_images, index)
# Out:
# img_path=  /content/gdrive/MyDrive/Colab Notebooks/gan_zero_colab/mnist_620.png

# %% [markdown]
# #Wyświetlenie prawdziwych obrazów poddawanychdyskryminatorowi

# %%
dcgan.plot_images(fake=False)

# %% [markdown]
# #

# %% [markdown]
# #Wykres dokładności (accuracy) modelu na zbiorze treningowym dla generatora

# %%
make_accuracy_plot(dcgan.accuracy_history_for_generator)

# %% [markdown]
# #wykres straty (loss) modelu na zbiorze treningowym dla generatora

# %%
make_loss_plot(dcgan.loss_history_for_generator)

# %% [markdown]
# #Wykres czasu uczenia się dla generatora

# %%
make_durration_plot(dcgan.duration_history_for_generator)

# %% [markdown]
# #Wykres dokładności (accuracy) modelu na zbiorze treningowym dla dyskryminatora

# %%
make_accuracy_plot(dcgan.accuracy_history_for_discriminator)

# %% [markdown]
# #wykres straty (loss) modelu na zbiorze treningowym dla dyskryminatora

# %%
make_loss_plot(dcgan.loss_history_for_discriminator)

# %% [markdown]
# #Wykres czasu uczenia się dla dyskryminatora

# %%
make_durration_plot(dcgan.duration_history_for_discriminator)
